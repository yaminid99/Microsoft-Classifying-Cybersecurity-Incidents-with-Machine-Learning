# %%
print("Yamini")
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("./data/GUIDE_Train.csv", low_memory = False)
# Out:
# Yamini

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9516837 entries, 0 to 9516836
# Data columns (total 45 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Id                  int64
#  1   OrgId               int64
#  2   IncidentId          int64
#  3   AlertId             int64
#  4   Timestamp           object
#  5   DetectorId          int64
#  6   AlertTitle          int64
#  7   Category            object
#  8   MitreTechniques     object
#  9   IncidentGrade       object
#  10  ActionGrouped       object
#  11  ActionGranular      object
#  12  EntityType          object
#  13  EvidenceRole        object
#  14  DeviceId            int64
#  15  Sha256              int64
#  16  IpAddress           int64
#  17  Url                 int64
#  18  AccountSid          int64
#  19  AccountUpn          int64
#  20  AccountObjectId     int64
#  21  AccountName         int64
#  22  DeviceName          int64
#  23  NetworkMessageId    int64
#  24  EmailClusterId      float64
#  25  RegistryKey         int64
#  26  RegistryValueName   int64
#  27  RegistryValueData   int64
#  28  ApplicationId       int64
#  29  ApplicationName     int64
#  30  OAuthApplicationId  int64
#  31  ThreatFamily        object
#  32  FileName            int64
#  33  FolderPath          int64
#  34  ResourceIdName      int64
#  35  ResourceType        object
#  36  Roles               object
#  37  OSFamily            int64
#  38  OSVersion           int64
#  39  AntispamDirection   object
#  40  SuspicionLevel      object
#  41  LastVerdict         object
#  42  CountryCode         int64
#  43  State               int64
#  44  City                int64
# dtypes: float64(1), int64(30), object(14)
# memory usage: 3.2+ GB

# %%
# Check for missing values
missing_values = df.isnull().sum()

missing_percentage = (missing_values / len(df)) * 100

print(missing_percentage)
# Out:
# Id                     0.000000
# OrgId                  0.000000
# IncidentId             0.000000
# AlertId                0.000000
# Timestamp              0.000000
# DetectorId             0.000000
# AlertTitle             0.000000
# Category               0.000000
# MitreTechniques       57.460120
# IncidentGrade          0.539465
# ActionGrouped         99.410897
# ActionGranular        99.410897
# EntityType             0.000000
# EvidenceRole           0.000000
# DeviceId               0.000000
# Sha256                 0.000000
# IpAddress              0.000000
# Url                    0.000000
# AccountSid             0.000000
# AccountUpn             0.000000
# AccountObjectId        0.000000
# AccountName            0.000000
# DeviceName             0.000000
# NetworkMessageId       0.000000
# EmailClusterId        98.982729
# RegistryKey            0.000000
# RegistryValueName      0.000000
# RegistryValueData      0.000000
# ApplicationId          0.000000
# ApplicationName        0.000000
# OAuthApplicationId     0.000000
# ThreatFamily          99.213173
# FileName               0.000000
# FolderPath             0.000000
# ResourceIdName         0.000000
# ResourceType          99.925658
# Roles                 97.707736
# OSFamily               0.000000
# OSVersion              0.000000
# AntispamDirection     98.136965
# SuspicionLevel        84.825536
# LastVerdict           76.523030
# CountryCode            0.000000
# State                  0.000000
# City                   0.000000
# dtype: float64

# %%
df.describe()
# Out:
#                  Id         OrgId    IncidentId       AlertId    DetectorId  \
# count  9.516837e+06  9.516837e+06  9.516837e+06  9.516837e+06  9.516837e+06
# mean   8.425494e+11  1.815800e+02  7.066349e+04  4.065188e+05  1.106724e+02
# std    4.962499e+11  3.867784e+02  1.208369e+05  4.592827e+05  4.351038e+02
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    4.123169e+11  1.000000e+01  5.040000e+02  2.324200e+04  2.000000e+00
# 50%    8.418136e+11  4.500000e+01  1.033600e+04  2.166520e+05  9.000000e+00
# 75%    1.271310e+12  1.710000e+02  8.432900e+04  6.715770e+05  4.500000e+01
# max    1.709397e+12  6.147000e+03  5.997060e+05  1.721456e+06  9.522000e+03
#
#          AlertTitle      DeviceId        Sha256     IpAddress           Url  \
# count  9.516837e+06  9.516837e+06  9.516837e+06  9.516837e+06  9.516837e+06
# mean   2.947315e+03  9.566476e+04  1.287191e+05  2.857506e+05  1.503317e+05
# std    1.146150e+04  1.635288e+04  3.399208e+04  1.412240e+05  3.750795e+04
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.000000e+00  9.879900e+04  1.382680e+05  3.606060e+05  1.603960e+05
# 50%    1.100000e+01  9.879900e+04  1.382680e+05  3.606060e+05  1.603960e+05
# 75%    1.800000e+02  9.879900e+04  1.382680e+05  3.606060e+05  1.603960e+05
# max    1.131740e+05  9.879900e+04  1.382680e+05  3.606060e+05  1.603960e+05
#
#        ...  ApplicationName  OAuthApplicationId      FileName    FolderPath  \
# count  ...     9.516837e+06        9.516837e+06  9.516837e+06  9.516837e+06
# mean   ...     3.342790e+03        8.807955e+02  2.622621e+05  1.076172e+05
# std    ...     5.103381e+02        1.291083e+01  8.152956e+04  3.220835e+04
# min    ...     0.000000e+00        0.000000e+00  0.000000e+00  0.000000e+00
# 25%    ...     3.421000e+03        8.810000e+02  2.895730e+05  1.176680e+05
# 50%    ...     3.421000e+03        8.810000e+02  2.895730e+05  1.176680e+05
# 75%    ...     3.421000e+03        8.810000e+02  2.895730e+05  1.176680e+05
# max    ...     3.421000e+03        8.810000e+02  2.895730e+05  1.176680e+05
#
#        ResourceIdName      OSFamily     OSVersion   CountryCode         State  \
# count    9.516837e+06  9.516837e+06  9.516837e+06  9.516837e+06  9.516837e+06
# mean     3.583477e+03  4.898537e+00  6.465558e+01  2.236742e+02  1.351488e+03
# std      9.020262e+01  7.035099e-01  9.314929e+00  6.279729e+01  3.509808e+02
# min      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%      3.586000e+03  5.000000e+00  6.600000e+01  2.420000e+02  1.445000e+03
# 50%      3.586000e+03  5.000000e+00  6.600000e+01  2.420000e+02  1.445000e+03
# 75%      3.586000e+03  5.000000e+00  6.600000e+01  2.420000e+02  1.445000e+03
# max      3.586000e+03  5.000000e+00  6.600000e+01  2.420000e+02  1.445000e+03
#
#                City
# count  9.516837e+06
# mean   9.936183e+03
# std    2.606812e+03
# min    0.000000e+00
# 25%    1.063000e+04
# 50%    1.063000e+04
# 75%    1.063000e+04
# max    1.063000e+04
#
# [8 rows x 31 columns]

# %%
df.describe(include=['object'])
# Out:
#                        Timestamp       Category  MitreTechniques  \
# count                    9516837        9516837          4048451
# unique                    760944             20             1193
# top     2024-06-12T01:27:49.000Z  InitialAccess  T1078;T1078.004
# freq                       11292        4293041          1354904
#
#          IncidentGrade   ActionGrouped  \
# count          9465497           56064
# unique               3               3
# top     BenignPositive  ContainAccount
# freq           4110817           53760
#
#                                     ActionGranular EntityType EvidenceRole  \
# count                                        56064    9516837      9516837
# unique                                          16         33            2
# top     update stsrefreshtokenvalidfrom timestamp.         Ip      Related
# freq                                         21393    2181194      5208644
#
#        ThreatFamily     ResourceType       Roles AntispamDirection  \
# count         74881             7075      218151            177302
# unique         1745               25          10                 5
# top           Phish  Virtual Machine  Contextual           Inbound
# freq           3526             4146      130528            161111
#
#        SuspicionLevel LastVerdict
# count         1444129     2234265
# unique              2           5
# top        Suspicious  Suspicious
# freq          1442614     1402997

# %%
df.nunique()
# Out:
# Id                     730778
# OrgId                    5769
# IncidentId             466151
# AlertId               1265644
# Timestamp              760944
# DetectorId               8428
# AlertTitle              86149
# Category                   20
# MitreTechniques          1193
# IncidentGrade               3
# ActionGrouped               3
# ActionGranular             16
# EntityType                 33
# EvidenceRole                2
# DeviceId                75826
# Sha256                 106416
# IpAddress              285957
# Url                    123252
# AccountSid             358401
# AccountUpn             530183
# AccountObjectId        343516
# AccountName            368250
# DeviceName             114541
# NetworkMessageId       375196
# EmailClusterId          26474
# RegistryKey              1341
# RegistryValueName         525
# RegistryValueData         699
# ApplicationId            1728
# ApplicationName          2681
# OAuthApplicationId        703
# ThreatFamily             1745
# FileName               222085
# FolderPath              87832
# ResourceIdName           2309
# ResourceType               25
# Roles                      10
# OSFamily                    6
# OSVersion                  58
# AntispamDirection           5
# SuspicionLevel              2
# LastVerdict                 5
# CountryCode               236
# State                    1368
# City                     9342
# dtype: int64

# %%
# Distribution of a specific categorical column
print(df['Category'].value_counts(), df['IncidentGrade'].value_counts(), df['ActionGrouped'].value_counts() )


# Distribution of numerical columns
print(df['Timestamp'].value_counts())
# Out:
# Category
# InitialAccess          4293041
# Exfiltration           1577965
# SuspiciousActivity     1003933
# CommandAndControl       826691
# Impact                  750885
# CredentialAccess        300518
# Execution               267594
# Malware                 144081
# Discovery               129342
# Persistence              72682
# DefenseEvasion           46662
# LateralMovement          41754
# Ransomware               18974
# UnwantedSoftware         18211
# Collection               14753
# PrivilegeEscalation       4671
# Exploit                   4648
# CredentialStealing         388
# WebExploit                  38
# Weaponization                6
# Name: count, dtype: int64 IncidentGrade
# BenignPositive    4110817
# TruePositive      3322713
# FalsePositive     2031967
# Name: count, dtype: int64 ActionGrouped
# ContainAccount           53760
# IsolateDevice             2237
# Stop Virtual Machines       67
# Name: count, dtype: int64
# Timestamp
# 2024-06-12T01:27:49.000Z    11292
# 2024-06-11T16:33:15.000Z     2689
# 2024-06-03T11:48:56.000Z     2415
# 2024-06-09T23:29:15.000Z     1490
# 2024-06-07T22:16:14.000Z     1473
#                             ...
# 2024-06-14T18:32:41.000Z        1
# 2024-06-09T04:26:51.000Z        1
# 2024-06-08T08:37:35.000Z        1
# 2024-06-10T08:18:03.000Z        1
# 2024-06-08T15:20:34.000Z        1
# Name: count, Length: 760944, dtype: int64

# %%
pd.set_option("display.max_column", None)

# %%
df.head()
# Out:
#               Id  OrgId  IncidentId  AlertId                 Timestamp  \
# 0   180388628218      0         612   123247  2024-06-04T06:05:15.000Z
# 1   455266534868     88         326   210035  2024-06-14T03:01:25.000Z
# 2  1056561957389    809       58352   712507  2024-06-13T04:52:55.000Z
# 3  1279900258736     92       32992   774301  2024-06-10T16:39:36.000Z
# 4   214748368522    148        4359   188041  2024-06-15T01:08:07.000Z
#
#    DetectorId  AlertTitle           Category MitreTechniques   IncidentGrade  \
# 0           7           6      InitialAccess             NaN    TruePositive
# 1          58          43       Exfiltration             NaN   FalsePositive
# 2         423         298      InitialAccess           T1189   FalsePositive
# 3           2           2  CommandAndControl             NaN  BenignPositive
# 4           9          74          Execution             NaN    TruePositive
#
#   ActionGrouped ActionGranular EntityType EvidenceRole  DeviceId  Sha256  \
# 0           NaN            NaN         Ip      Related     98799  138268
# 1           NaN            NaN       User     Impacted     98799  138268
# 2           NaN            NaN        Url      Related     98799  138268
# 3           NaN            NaN        Url      Related     98799  138268
# 4           NaN            NaN       User     Impacted     98799  138268
#
#    IpAddress     Url  AccountSid  AccountUpn  AccountObjectId  AccountName  \
# 0         27  160396      441377      673934           425863       453297
# 1     360606  160396       22406       23032            22795        24887
# 2     360606   68652      441377      673934           425863       453297
# 3     360606      13      441377      673934           425863       453297
# 4     360606  160396         449         592              440          479
#
#    DeviceName  NetworkMessageId  EmailClusterId  RegistryKey  \
# 0      153085            529644             NaN         1631
# 1      153085            529644             NaN         1631
# 2      153085            529644             NaN         1631
# 3      153085            529644             NaN         1631
# 4      153085            529644             NaN         1631
#
#    RegistryValueName  RegistryValueData  ApplicationId  ApplicationName  \
# 0                635                860           2251             3421
# 1                635                860           2251             3421
# 2                635                860           2251             3421
# 3                635                860           2251             3421
# 4                635                860           2251             3421
#
#    OAuthApplicationId ThreatFamily  FileName  FolderPath  ResourceIdName  \
# 0                 881          NaN    289573      117668            3586
# 1                 881          NaN    289573      117668            3586
# 2                 881          NaN    289573      117668            3586
# 3                 881          NaN    289573      117668            3586
# 4                 881          NaN    289573      117668            3586
#
#   ResourceType Roles  OSFamily  OSVersion AntispamDirection SuspicionLevel  \
# 0          NaN   NaN         5         66               NaN            NaN
# 1          NaN   NaN         5         66               NaN            NaN
# 2          NaN   NaN         5         66               NaN     Suspicious
# 3          NaN   NaN         5         66               NaN     Suspicious
# 4          NaN   NaN         5         66               NaN            NaN
#
#   LastVerdict  CountryCode  State   City
# 0         NaN           31      6      3
# 1         NaN          242   1445  10630
# 2  Suspicious          242   1445  10630
# 3  Suspicious          242   1445  10630
# 4         NaN          242   1445  10630

# %%
# Cross-tabulation for 'Category' and 'IncidentGrade'
crosstab_result = pd.crosstab(df['Category'], df['IncidentGrade'])

crosstab_result
# Out:
# IncidentGrade        BenignPositive  FalsePositive  TruePositive
# Category
# Collection                     5519           7063          1876
# CommandAndControl            563544         145508        116564
# CredentialAccess             118709          71416        109912
# CredentialStealing                0            377             9
# DefenseEvasion                21495          14069         10735
# Discovery                     71352          34224         22424
# Execution                    134108          87870         44813
# Exfiltration                1080813         368866        101077
# Exploit                        2569            653          1417
# Impact                       336977         171348        242524
# InitialAccess               1063722         954880       2266513
# LateralMovement               26878           8924          5391
# Malware                       91937          19214         32440
# Persistence                   55973          12906          3635
# PrivilegeEscalation            4147            417           101
# Ransomware                    12520            306          4577
# SuspiciousActivity           507279         131427        356286
# UnwantedSoftware              13245           2497          2407
# Weaponization                     0              0             6
# WebExploit                       30              2             6

# %%
# Select only numeric columns for correlation
numeric_df = df.select_dtypes(include=['int64', 'float64'])
corr_matrix = numeric_df.corr()

# Example: Correlation heatmap
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Example: Distribution of IncidentGrade
sns.countplot(x='IncidentGrade', data=df)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns

for col in numeric_columns:
    plt.figure(figsize=(10, 4))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

pivot = pd.pivot_table(df, values='IncidentId', index=['Category'], columns=['IncidentGrade'], aggfunc='count')
sns.heatmap(pivot, annot=True, cmap='Blues')
plt.title('Incident Counts by Category and Grade')
plt.show()

# %%
import pandas as pd

# Display the data types of each column before conversion
print("\nData types of each column before conversion:", df.dtypes)


# Convert all non-object columns to 'category' data type, leave object columns unchanged
for col in df.select_dtypes(exclude='object').columns:
    df[col] = df[col].astype('category')

# Function to replace low-frequency categories with 'Others'
def replace_with_top_categories(df, max_categories=5):
    for col in df.columns:
        if df[col].dtype.name == 'category':
            # Get value counts of the column
            value_counts = df[col].value_counts()
            
            if len(value_counts) > max_categories:
                # Identify top `max_categories` categories
                top_categories = value_counts.nlargest(max_categories).index
                # Replace all other categories with 'Others'
                df[col] = pd.Categorical(
                    df[col].apply(lambda x: x if x in top_categories else 'Others'),
                    categories=top_categories.union(['Others'])
                )
    return df

# Calculate and print the percentage of each category in all columns before replacement
for col in df.columns:
    print(f"\nCategory percentages for column {col} before replacement:")
    print(df[col].value_counts(normalize=True) * 100)

# Apply the function to replace low-frequency categories with 'Others'
df = replace_with_top_categories(df, max_categories=20)

# Calculate and print the percentage of each category in all columns after replacement
for col in df.columns:
    print(f"\nCategory percentages for column {col} after replacement:", df[col].value_counts(normalize=True) * 100)

# Display the data types of each column after conversion
print("\nData types of each column after conversion:", df.dtypes)
# Out:
# Data types of each column before conversion: Id                      int64
# OrgId                   int64
# IncidentId              int64
# AlertId                 int64
# Timestamp              object
# DetectorId              int64
# AlertTitle              int64
# Category               object
# MitreTechniques        object
# IncidentGrade          object
# ActionGrouped          object
# ActionGranular         object
# EntityType             object
# EvidenceRole           object
# DeviceId                int64
# Sha256                  int64
# IpAddress               int64
# Url                     int64
# AccountSid              int64
# AccountUpn              int64
# AccountObjectId         int64
# AccountName             int64
# DeviceName              int64
# NetworkMessageId        int64
# EmailClusterId        float64
# RegistryKey             int64
# RegistryValueName       int64
# RegistryValueData       int64
# ApplicationId           int64
# ApplicationName         int64
# OAuthApplicationId      int64
# ThreatFamily           object
# FileName                int64
# FolderPath              int64
# ResourceIdName          int64
# ResourceType           object
# Roles                  object
# OSFamily                int64
# OSVersion               int64
# AntispamDirection      object
# SuspicionLevel         object
# LastVerdict            object
# CountryCode             int64
# State                   int64
# City                    int64
# dtype: object
#
# Category percentages for column Id before replacement:
# Id
# 601295424398     0.315199
# 609885356628     0.215534
# 1666447311459    0.122373
# 1417339210481    0.107473
# 635655161844     0.107115
#                    ...
# 858993462016     0.000011
# 858993462007     0.000011
# 858993462001     0.000011
# 858993461994     0.000011
# 85899349784      0.000011
# Name: proportion, Length: 730778, dtype: float64
#
# Category percentages for column OrgId before replacement:
# OrgId
# 0       8.879095
# 2       2.535822
# 1       2.207519
# 3       2.005572
# 5       1.822591
#           ...
# 6073    0.000011
# 6071    0.000011
# 6070    0.000011
# 6067    0.000011
# 6147    0.000011
# Name: proportion, Length: 5769, dtype: float64
#
# Category percentages for column IncidentId before replacement:
# IncidentId
# 0         0.315199
# 2         0.215670
# 7         0.128740
# 9         0.122478
# 14        0.107473
#             ...
# 583706    0.000011
# 583705    0.000011
# 583704    0.000011
# 583703    0.000011
# 599706    0.000011
# Name: proportion, Length: 466151, dtype: float64
#
# Category percentages for column AlertId before replacement:
# AlertId
# 0          0.118653
# 3          0.028171
# 2          0.025197
# 5          0.015572
# 6          0.015478
#              ...
# 1671565    0.000011
# 1671564    0.000011
# 1671563    0.000011
# 1671562    0.000011
# 1721456    0.000011
# Name: proportion, Length: 1265644, dtype: float64
#
# Category percentages for column Timestamp before replacement:
# Timestamp
# 2024-06-12T01:27:49.000Z    0.118653
# 2024-06-11T16:33:15.000Z    0.028255
# 2024-06-03T11:48:56.000Z    0.025376
# 2024-06-09T23:29:15.000Z    0.015656
# 2024-06-07T22:16:14.000Z    0.015478
#                               ...
# 2024-06-14T18:32:41.000Z    0.000011
# 2024-06-09T04:26:51.000Z    0.000011
# 2024-06-08T08:37:35.000Z    0.000011
# 2024-06-10T08:18:03.000Z    0.000011
# 2024-06-08T15:20:34.000Z    0.000011
# Name: proportion, Length: 760944, dtype: float64
#
# Category percentages for column DetectorId before replacement:
# DetectorId
# 0       13.998685
# 1        8.138618
# 2        6.278315
# 3        5.159445
# 4        4.330084
#           ...
# 9088     0.000011
# 9086     0.000011
# 9085     0.000011
# 9084     0.000011
# 9522     0.000011
# Name: proportion, Length: 8428, dtype: float64
#
# Category percentages for column AlertTitle before replacement:
# AlertTitle
# 0         13.998685
# 1          8.138618
# 2          6.278315
# 4          4.348913
# 3          4.330084
#             ...
# 110341     0.000011
# 110344     0.000011
# 110345     0.000011
# 110346     0.000011
# 113174     0.000011
# Name: proportion, Length: 86149, dtype: float64
#
# Category percentages for column Category before replacement:
# Category
# InitialAccess          45.109956
# Exfiltration           16.580772
# SuspiciousActivity     10.549020
# CommandAndControl       8.686615
# Impact                  7.890069
# CredentialAccess        3.157751
# Execution               2.811796
# Malware                 1.513959
# Discovery               1.359086
# Persistence             0.763720
# DefenseEvasion          0.490310
# LateralMovement         0.438738
# Ransomware              0.199373
# UnwantedSoftware        0.191356
# Collection              0.155020
# PrivilegeEscalation     0.049081
# Exploit                 0.048840
# CredentialStealing      0.004077
# WebExploit              0.000399
# Weaponization           0.000063
# Name: proportion, dtype: float64
#
# Category percentages for column MitreTechniques before replacement:
# MitreTechniques
# T1078;T1078.004                                        33.467220
# T1566.002                                              20.114063
# T1566                                                  16.292429
# T1133                                                   3.595919
# T1566.001                                               3.381343
#                                                          ...
# T1084                                                   0.000025
# T1055;T1055.003;T1055.012;T1059;T1059.001;T1106         0.000025
# T1003.001;T1055;T1055.003;T1055.012;T1106;T1550.002     0.000025
# T1055;T1055.002;T1055.003;T1055.012;T1078;T1106         0.000025
# T1078;T1078.001                                         0.000025
# Name: proportion, Length: 1193, dtype: float64
#
# Category percentages for column IncidentGrade before replacement:
# IncidentGrade
# BenignPositive    43.429489
# TruePositive      35.103418
# FalsePositive     21.467093
# Name: proportion, dtype: float64
#
# Category percentages for column ActionGrouped before replacement:
# ActionGrouped
# ContainAccount           95.890411
# IsolateDevice             3.990083
# Stop Virtual Machines     0.119506
# Name: proportion, dtype: float64
#
# Category percentages for column ActionGranular before replacement:
# ActionGranular
# update stsrefreshtokenvalidfrom timestamp.    38.158176
# account password changed                      25.076698
# change user password.                         24.299015
# isolateresponse                                3.644050
# account disabled                               3.551299
# disable account.                               2.038741
# reset user password.                           1.580337
# forcepasswordresetremediation                  0.417380
# quarantinefile                                 0.346033
# msecidentitiesconfirmusercompromised           0.260417
# disableuser                                    0.190853
# msecidentitiessuspenduser                      0.144478
# delete virtualmachines                         0.119506
# account deleted                                0.098102
# delete user.                                   0.062429
# set force change user password.                0.012486
# Name: proportion, dtype: float64
#
# Category percentages for column EntityType before replacement:
# EntityType
# Ip                       22.919317
# User                     20.305234
# MailMessage              12.327142
# Machine                   7.347063
# File                      7.233517
# Url                       7.172320
# CloudLogonRequest         6.709845
# Mailbox                   5.076876
# Process                   3.632846
# MailCluster               2.360910
# CloudApplication          2.278183
# CloudLogonSession         2.231645
# RegistryValue             0.117781
# AzureResource             0.085806
# RegistryKey               0.076464
# GenericEntity             0.045120
# OAuthApplication          0.027267
# Malware                   0.027110
# SecurityGroup             0.015951
# BlobContainer             0.003215
# Blob                      0.002764
# MailboxConfiguration      0.002375
# Nic                       0.000515
# IoTDevice                 0.000326
# ActiveDirectoryDomain     0.000116
# GoogleCloudResource       0.000105
# AmazonResource            0.000063
# Container                 0.000021
# KubernetesCluster         0.000021
# ContainerImage            0.000021
# KubernetesNamespace       0.000021
# KubernetesPod             0.000021
# ContainerRegistry         0.000021
# Name: proportion, dtype: float64
#
# Category percentages for column EvidenceRole before replacement:
# EvidenceRole
# Related     54.730831
# Impacted    45.269169
# Name: proportion, dtype: float64
#
# Category percentages for column DeviceId before replacement:
# DeviceId
# 98799    96.187147
# 0         0.049575
# 1         0.041936
# 4         0.023001
# 5         0.022476
#            ...
# 65817     0.000011
# 65816     0.000011
# 65814     0.000011
# 65811     0.000011
# 68065     0.000011
# Name: proportion, Length: 75826, dtype: float64
#
# Category percentages for column Sha256 before replacement:
# Sha256
# 138268    92.300246
# 0          0.530460
# 1          0.289928
# 2          0.167261
# 3          0.160831
#             ...
# 87068      0.000011
# 87070      0.000011
# 87071      0.000011
# 87072      0.000011
# 92936      0.000011
# Name: proportion, Length: 106416, dtype: float64
#
# Category percentages for column IpAddress before replacement:
# IpAddress
# 360606    77.117681
# 0          0.131231
# 3          0.103690
# 1          0.102545
# 2          0.097154
#             ...
# 209884     0.000011
# 209882     0.000011
# 209881     0.000011
# 209878     0.000011
# 152892     0.000011
# Name: proportion, Length: 285957, dtype: float64
#
# Category percentages for column Url before replacement:
# Url
# 160396    92.826335
# 0          0.086142
# 1          0.069424
# 2          0.055312
# 6          0.044532
#             ...
# 110626     0.000011
# 110627     0.000011
# 110628     0.000011
# 110629     0.000011
# 107473     0.000011
# Name: proportion, Length: 123252, dtype: float64
#
# Category percentages for column AccountSid before replacement:
# AccountSid
# 441377    76.311646
# 0          0.152036
# 1          0.113903
# 2          0.063225
# 3          0.055291
#             ...
# 325445     0.000011
# 325444     0.000011
# 325442     0.000011
# 325441     0.000011
# 345051     0.000011
# Name: proportion, Length: 358401, dtype: float64
#
# Category percentages for column AccountUpn before replacement:
# AccountUpn
# 673934    63.598294
# 0          0.152036
# 1          0.099235
# 2          0.089757
# 4          0.081960
#             ...
# 477270     0.000011
# 477271     0.000011
# 477272     0.000011
# 477273     0.000011
# 303634     0.000011
# Name: proportion, Length: 530183, dtype: float64
#
# Category percentages for column AccountObjectId before replacement:
# AccountObjectId
# 425863    76.562150
# 0          0.152036
# 1          0.113903
# 2          0.063225
# 3          0.039614
#             ...
# 321231     0.000011
# 321230     0.000011
# 321229     0.000011
# 321228     0.000011
# 318577     0.000011
# Name: proportion, Length: 343516, dtype: float64
#
# Category percentages for column AccountName before replacement:
# AccountName
# 453297    75.132736
# 0          0.152036
# 1          0.113903
# 2          0.064181
# 3          0.039625
#             ...
# 329131     0.000011
# 329130     0.000011
# 329129     0.000011
# 329127     0.000011
# 332055     0.000011
# Name: proportion, Length: 368250, dtype: float64
#
# Category percentages for column DeviceName before replacement:
# DeviceName
# 153085    92.674131
# 0          0.045982
# 1          0.041442
# 5          0.022623
# 4          0.022613
#             ...
# 92443      0.000011
# 92444      0.000011
# 92447      0.000011
# 92448      0.000011
# 63582      0.000011
# Name: proportion, Length: 114541, dtype: float64
#
# Category percentages for column NetworkMessageId before replacement:
# NetworkMessageId
# 529644    87.823276
# 0          0.028718
# 3          0.008932
# 1          0.007744
# 7          0.007355
#             ...
# 346381     0.000011
# 346382     0.000011
# 346384     0.000011
# 346386     0.000011
# 369137     0.000011
# Name: proportion, Length: 375196, dtype: float64
#
# Category percentages for column EmailClusterId before replacement:
# EmailClusterId
# 4218786605.0    2.055530
# 4023349548.0    1.966698
# 4140628171.0    1.793166
# 1962111205.0    0.851134
# 2834092745.0    0.614593
#                   ...
# 3168219798.0    0.001033
# 3168206124.0    0.001033
# 3168194092.0    0.001033
# 3168192698.0    0.001033
# 4294966974.0    0.001033
# Name: proportion, Length: 26474, dtype: float64
#
# Category percentages for column RegistryKey before replacement:
# RegistryKey
# 1631    99.815863
# 0        0.116383
# 1        0.002574
# 3        0.002469
# 6        0.001482
#           ...
# 384      0.000011
# 383      0.000011
# 382      0.000011
# 381      0.000011
# 1048     0.000011
# Name: proportion, Length: 1341, dtype: float64
#
# Category percentages for column RegistryValueName before replacement:
# RegistryValueName
# 635    99.952926
# 1       0.005075
# 0       0.005075
# 5       0.003268
# 6       0.002690
#          ...
# 449     0.000011
# 243     0.000011
# 239     0.000011
# 234     0.000011
# 295     0.000011
# Name: proportion, Length: 525, dtype: float64
#
# Category percentages for column RegistryValueData before replacement:
# RegistryValueData
# 860    99.943195
# 0       0.014679
# 2       0.004760
# 1       0.002911
# 4       0.002228
#          ...
# 539     0.000011
# 538     0.000011
# 537     0.000011
# 536     0.000011
# 549     0.000011
# Name: proportion, Length: 699, dtype: float64
#
# Category percentages for column ApplicationId before replacement:
# ApplicationId
# 2251    97.762881
# 0        0.649670
# 1        0.403149
# 2        0.385443
# 3        0.333441
#           ...
# 1076     0.000011
# 1075     0.000011
# 1070     0.000011
# 1069     0.000011
# 992      0.000011
# Name: proportion, Length: 1728, dtype: float64
#
# Category percentages for column ApplicationName before replacement:
# ApplicationName
# 3421    97.696661
# 0        0.650258
# 1        0.403769
# 2        0.385307
# 3        0.333472
#           ...
# 1678     0.000011
# 1677     0.000011
# 1676     0.000011
# 1675     0.000011
# 1463     0.000011
# Name: proportion, Length: 2681, dtype: float64
#
# Category percentages for column OAuthApplicationId before replacement:
# OAuthApplicationId
# 881    99.972733
# 0       0.006347
# 1       0.002081
# 2       0.001839
# 3       0.000778
#          ...
# 445     0.000011
# 444     0.000011
# 440     0.000011
# 439     0.000011
# 371     0.000011
# Name: proportion, Length: 703, dtype: float64
#
# Category percentages for column ThreatFamily before replacement:
# ThreatFamily
# Phish                        4.708805
# Malgent                      3.520252
# Donoff                       3.364004
# CustomEnterpriseBlock        2.864545
# CustomEnterpriseBlockOnly    2.856532
#                                ...
# AprilAxe                     0.001335
# Kechang                      0.001335
# PolsckiCrypt                 0.001335
# GhostRadmin                  0.001335
# Gootkit                      0.001335
# Name: proportion, Length: 1745, dtype: float64
#
# Category percentages for column FileName before replacement:
# FileName
# 289573    89.188141
# 0          0.921903
# 1          0.746141
# 2          0.191177
# 3          0.161640
#             ...
# 160489     0.000011
# 160488     0.000011
# 160482     0.000011
# 160481     0.000011
# 126151     0.000011
# Name: proportion, Length: 222085, dtype: float64
#
# Category percentages for column FolderPath before replacement:
# FolderPath
# 117668    90.799117
# 0          1.195607
# 1          0.742736
# 2          0.640580
# 3          0.420098
#             ...
# 73252      0.000011
# 73253      0.000011
# 73254      0.000011
# 73255      0.000011
# 78338      0.000011
# Name: proportion, Length: 87832, dtype: float64
#
# Category percentages for column ResourceIdName before replacement:
# ResourceIdName
# 3586    99.914194
# 0        0.004098
# 1        0.003457
# 2        0.002879
# 3        0.002658
#           ...
# 2075     0.000011
# 2074     0.000011
# 2072     0.000011
# 2062     0.000011
# 2312     0.000011
# Name: proportion, Length: 2309, dtype: float64
#
# Category percentages for column ResourceType before replacement:
# ResourceType
# Virtual Machine                         58.600707
# Key Vault                                6.784452
# App Service                              5.710247
# Azure Arc machine                        5.272085
# Storage Account                          5.173145
# Subscription                             3.830389
# SQL Database                             3.194346
# Azure Database for MySQL Server          2.572438
# Azure Resource                           2.219081
# Virtual Machine Scale Set                1.583039
# API Management Service                   1.328622
# Key Vault Secret                         1.088339
# Azure Database for PostgreSQL Server     0.636042
# SQL Server                               0.579505
# Azure Cosmos DB Account                  0.424028
# Networking                               0.197880
# Synapse SQL Pool                         0.155477
# GCP Compute Instance                     0.141343
# SQL Managed Instance                     0.127208
# Kubernetes Service                       0.127208
# Key Vault Certificate                    0.098940
# AWS EC2 Instance                         0.084806
# Key Vault Key                            0.028269
# Synapse Workspace                        0.028269
# Cognitive Service                        0.014134
# Name: proportion, dtype: float64
#
# Category percentages for column Roles before replacement:
# Roles
# Contextual        59.833785
# Destination       15.734056
# Suspicious        13.271541
# Attacker           6.003181
# Source             3.287173
# Compromised        1.475583
# PolicyViolator     0.305293
# Attacked           0.086179
# Edited             0.002750
# Added              0.000458
# Name: proportion, dtype: float64
#
# Category percentages for column OSFamily before replacement:
# OSFamily
# 5    97.958649
# 0     1.996840
# 1     0.028707
# 2     0.015720
# 3     0.000074
# 4     0.000011
# Name: proportion, dtype: float64
#
# Category percentages for column OSVersion before replacement:
# OSVersion
# 66    97.958723
# 0      1.969194
# 2      0.019881
# 1      0.017359
# 3      0.011821
# 4      0.007692
# 6      0.003804
# 5      0.002795
# 8      0.001387
# 9      0.001145
# 10     0.000935
# 7      0.000851
# 11     0.000694
# 12     0.000567
# 16     0.000399
# 13     0.000336
# 14     0.000326
# 15     0.000231
# 19     0.000189
# 17     0.000179
# 20     0.000168
# 22     0.000158
# 21     0.000147
# 24     0.000137
# 25     0.000074
# 26     0.000074
# 27     0.000063
# 31     0.000053
# 28     0.000053
# 33     0.000042
# 35     0.000042
# 29     0.000032
# 37     0.000032
# 38     0.000032
# 40     0.000032
# 41     0.000032
# 42     0.000032
# 43     0.000021
# 45     0.000021
# 44     0.000021
# 46     0.000021
# 30     0.000021
# 23     0.000021
# 34     0.000021
# 59     0.000011
# 65     0.000011
# 64     0.000011
# 63     0.000011
# 62     0.000011
# 60     0.000011
# 36     0.000011
# 58     0.000011
# 53     0.000011
# 52     0.000011
# 51     0.000011
# 48     0.000011
# 47     0.000011
# 56     0.000011
# Name: proportion, dtype: float64
#
# Category percentages for column AntispamDirection before replacement:
# AntispamDirection
# Inbound                                               90.868123
# Intraorg                                               8.633856
# Outbound                                               0.489560
# DomainPII_50d8b4a941c26b89482c94ab324b5a274f9ced66     0.005640
# DomainPII_df80ab894e01e375bf55d12ba315c04029d3e32d     0.002820
# Name: proportion, dtype: float64
#
# Category percentages for column SuspicionLevel before replacement:
# SuspicionLevel
# Suspicious      99.895092
# Incriminated     0.104908
# Name: proportion, dtype: float64
#
# Category percentages for column LastVerdict before replacement:
# LastVerdict
# Suspicious                                            62.794566
# Malicious                                             19.396043
# NoThreatsFound                                        17.800843
# DomainPII_50d8b4a941c26b89482c94ab324b5a274f9ced66     0.005729
# DomainPII_9207384283ce115db5a590dd9ca5de21e5e99df2     0.002820
# Name: proportion, dtype: float64
#
# Category percentages for column CountryCode before replacement:
# CountryCode
# 242    92.120018
# 0       1.820122
# 1       1.118082
# 2       0.563958
# 4       0.423407
#          ...
# 218     0.000011
# 192     0.000011
# 209     0.000011
# 215     0.000011
# 222     0.000011
# Name: proportion, Length: 236, dtype: float64
#
# Category percentages for column State before replacement:
# State
# 1445    93.348010
# 0        1.091413
# 1        0.423586
# 2        0.303410
# 3        0.242181
#           ...
# 1240     0.000011
# 1080     0.000011
# 1244     0.000011
# 1246     0.000011
# 1130     0.000011
# Name: proportion, Length: 1368, dtype: float64
#
# Category percentages for column City before replacement:
# City
# 10630    93.341380
# 0         1.086842
# 1         0.234773
# 2         0.204364
# 3         0.166915
#            ...
# 7461      0.000011
# 7466      0.000011
# 7467      0.000011
# 2294      0.000011
# 4722      0.000011
# Name: proportion, Length: 9342, dtype: float64
#
# Category percentages for column Id after replacement: Id
# Others           97.550772
# 601295424398      0.315199
# 609885356628      0.215534
# 1666447311459     0.122373
# 1417339210481     0.107473
# 635655161844      0.107115
# 670014901898      0.106338
# 403726927644      0.106296
# 1159641172187     0.105571
# 188978563521      0.105466
# 111669152214      0.105445
# 111669154679      0.105403
# 515396077947      0.105392
# 1511828490659     0.105277
# 1348619733421     0.105256
# 25769806671       0.105245
# 1297080128102     0.105203
# 1374389537640     0.105161
# 987842483055      0.105161
# 103079216833      0.105161
# 635655162268      0.105161
# Name: proportion, dtype: float64
#
# Category percentages for column OrgId after replacement: OrgId
# Others    64.660254
# 0          8.879095
# 2          2.535822
# 1          2.207519
# 3          2.005572
# 5          1.822591
# 6          1.692705
# 4          1.531402
# 7          1.413621
# 8          1.404437
# 10         1.399204
# 9          1.377180
# 11         1.220300
# 12         1.206283
# 14         1.184017
# 13         1.128137
# 16         0.923679
# 25         0.880996
# 17         0.855620
# 19         0.842381
# 18         0.829183
# Name: proportion, dtype: float64
#
# Category percentages for column IncidentId after replacement: IncidentId
# Others    97.525764
# 0          0.315199
# 2          0.215670
# 7          0.128740
# 9          0.122478
# 14         0.107473
# 17         0.107115
# 20         0.106401
# 21         0.106296
# 26         0.105571
# 24         0.105518
# 29         0.105466
# 27         0.105466
# 31         0.105445
# 34         0.105403
# 35         0.105392
# 32         0.105371
# 33         0.105361
# 39         0.105308
# 30         0.105287
# 40         0.105277
# Name: proportion, dtype: float64
#
# Category percentages for column AlertId after replacement: AlertId
# Others    99.628322
# 0          0.118653
# 3          0.028171
# 2          0.025197
# 5          0.015572
# 6          0.015478
# 8          0.014921
# 9          0.012063
# 12         0.011853
# 14         0.011727
# 17         0.011632
# 19         0.010970
# 20         0.010907
# 22         0.010865
# 24         0.010571
# 25         0.010539
# 26         0.010529
# 153        0.010508
# 154        0.010508
# 167        0.010508
# 176        0.010508
# Name: proportion, dtype: float64
#
# Category percentages for column Timestamp after replacement: Timestamp
# 2024-06-12T01:27:49.000Z    0.118653
# 2024-06-11T16:33:15.000Z    0.028255
# 2024-06-03T11:48:56.000Z    0.025376
# 2024-06-09T23:29:15.000Z    0.015656
# 2024-06-07T22:16:14.000Z    0.015478
#                               ...
# 2024-06-14T18:32:41.000Z    0.000011
# 2024-06-09T04:26:51.000Z    0.000011
# 2024-06-08T08:37:35.000Z    0.000011
# 2024-06-10T08:18:03.000Z    0.000011
# 2024-06-08T15:20:34.000Z    0.000011
# Name: proportion, Length: 760944, dtype: float64
#
# Category percentages for column DetectorId after replacement: DetectorId
# Others    37.877396
# 0         13.998685
# 1          8.138618
# 2          6.278315
# 3          5.159445
# 4          4.330084
# 5          3.591813
# 6          3.516420
# 7          3.247854
# 9          1.619372
# 8          1.529363
# 10         1.422847
# 12         1.375720
# 11         1.237796
# 15         1.019015
# 17         0.993450
# 16         0.983625
# 13         0.979748
# 18         0.954193
# 14         0.931623
# 19         0.814619
# Name: proportion, dtype: float64
#
# Category percentages for column AlertTitle after replacement: AlertTitle
# Others    43.678619
# 0         13.998685
# 1          8.138618
# 2          6.278315
# 4          4.348913
# 3          4.330084
# 5          3.516420
# 6          3.247854
# 7          1.529363
# 8          1.422847
# 9          1.237796
# 10         1.107406
# 13         1.020381
# 11         0.979748
# 14         0.956946
# 12         0.931623
# 15         0.814619
# 16         0.656636
# 17         0.629915
# 19         0.605191
# 20         0.570021
# Name: proportion, dtype: float64
#
# Category percentages for column Category after replacement: Category
# InitialAccess          45.109956
# Exfiltration           16.580772
# SuspiciousActivity     10.549020
# CommandAndControl       8.686615
# Impact                  7.890069
# CredentialAccess        3.157751
# Execution               2.811796
# Malware                 1.513959
# Discovery               1.359086
# Persistence             0.763720
# DefenseEvasion          0.490310
# LateralMovement         0.438738
# Ransomware              0.199373
# UnwantedSoftware        0.191356
# Collection              0.155020
# PrivilegeEscalation     0.049081
# Exploit                 0.048840
# CredentialStealing      0.004077
# WebExploit              0.000399
# Weaponization           0.000063
# Name: proportion, dtype: float64
#
# Category percentages for column MitreTechniques after replacement: MitreTechniques
# T1078;T1078.004                                        33.467220
# T1566.002                                              20.114063
# T1566                                                  16.292429
# T1133                                                   3.595919
# T1566.001                                               3.381343
#                                                          ...
# T1084                                                   0.000025
# T1055;T1055.003;T1055.012;T1059;T1059.001;T1106         0.000025
# T1003.001;T1055;T1055.003;T1055.012;T1106;T1550.002     0.000025
# T1055;T1055.002;T1055.003;T1055.012;T1078;T1106         0.000025
# T1078;T1078.001                                         0.000025
# Name: proportion, Length: 1193, dtype: float64
#
# Category percentages for column IncidentGrade after replacement: IncidentGrade
# BenignPositive    43.429489
# TruePositive      35.103418
# FalsePositive     21.467093
# Name: proportion, dtype: float64
#
# Category percentages for column ActionGrouped after replacement: ActionGrouped
# ContainAccount           95.890411
# IsolateDevice             3.990083
# Stop Virtual Machines     0.119506
# Name: proportion, dtype: float64
#
# Category percentages for column ActionGranular after replacement: ActionGranular
# update stsrefreshtokenvalidfrom timestamp.    38.158176
# account password changed                      25.076698
# change user password.                         24.299015
# isolateresponse                                3.644050
# account disabled                               3.551299
# disable account.                               2.038741
# reset user password.                           1.580337
# forcepasswordresetremediation                  0.417380
# quarantinefile                                 0.346033
# msecidentitiesconfirmusercompromised           0.260417
# disableuser                                    0.190853
# msecidentitiessuspenduser                      0.144478
# delete virtualmachines                         0.119506
# account deleted                                0.098102
# delete user.                                   0.062429
# set force change user password.                0.012486
# Name: proportion, dtype: float64
#
# Category percentages for column EntityType after replacement: EntityType
# Ip                       22.919317
# User                     20.305234
# MailMessage              12.327142
# Machine                   7.347063
# File                      7.233517
# Url                       7.172320
# CloudLogonRequest         6.709845
# Mailbox                   5.076876
# Process                   3.632846
# MailCluster               2.360910
# CloudApplication          2.278183
# CloudLogonSession         2.231645
# RegistryValue             0.117781
# AzureResource             0.085806
# RegistryKey               0.076464
# GenericEntity             0.045120
# OAuthApplication          0.027267
# Malware                   0.027110
# SecurityGroup             0.015951
# BlobContainer             0.003215
# Blob                      0.002764
# MailboxConfiguration      0.002375
# Nic                       0.000515
# IoTDevice                 0.000326
# ActiveDirectoryDomain     0.000116
# GoogleCloudResource       0.000105
# AmazonResource            0.000063
# Container                 0.000021
# KubernetesCluster         0.000021
# ContainerImage            0.000021
# KubernetesNamespace       0.000021
# KubernetesPod             0.000021
# ContainerRegistry         0.000021
# Name: proportion, dtype: float64
#
# Category percentages for column EvidenceRole after replacement: EvidenceRole
# Related     54.730831
# Impacted    45.269169
# Name: proportion, dtype: float64
#
# Category percentages for column DeviceId after replacement: DeviceId
# 98799     96.187147
# Others     3.469062
# 0          0.049575
# 1          0.041936
# 4          0.023001
# 5          0.022476
# 6          0.019744
# 12         0.019460
# 7          0.017590
# 8          0.017138
# 10         0.016602
# 9          0.015888
# 11         0.013492
# 13         0.013145
# 15         0.012819
# 16         0.011506
# 14         0.011495
# 18         0.010539
# 22         0.009793
# 23         0.009047
# 17         0.008543
# Name: proportion, dtype: float64
#
# Category percentages for column Sha256 after replacement: Sha256
# 138268    92.300246
# Others     5.663688
# 0          0.530460
# 1          0.289928
# 2          0.167261
# 3          0.160831
# 4          0.120250
# 5          0.089788
# 6          0.079638
# 7          0.078482
# 8          0.077894
# 12         0.053148
# 10         0.052696
# 11         0.052160
# 9          0.051950
# 13         0.046265
# 15         0.042871
# 14         0.042619
# 16         0.037670
# 19         0.033341
# 17         0.028812
# Name: proportion, dtype: float64
#
# Category percentages for column IpAddress after replacement: IpAddress
# 360606    77.117681
# Others    21.620072
# 0          0.131231
# 3          0.103690
# 1          0.102545
# 2          0.097154
# 4          0.083830
# 7          0.073281
# 5          0.070664
# 6          0.070202
# 8          0.059064
# 9          0.055323
# 11         0.053705
# 13         0.049365
# 12         0.047799
# 14         0.046307
# 18         0.044532
# 19         0.044532
# 20         0.044532
# 17         0.042861
# 10         0.041631
# Name: proportion, dtype: float64
#
# Category percentages for column Url after replacement: Url
# 160396    92.826335
# Others     6.561613
# 0          0.086142
# 1          0.069424
# 2          0.055312
# 6          0.044532
# 3          0.039982
# 4          0.036409
# 5          0.035894
# 7          0.024535
# 9          0.022917
# 11         0.022739
# 10         0.021583
# 8          0.021341
# 12         0.020564
# 14         0.020259
# 16         0.019723
# 13         0.019092
# 17         0.017663
# 15         0.017432
# 18         0.016508
# Name: proportion, dtype: float64
#
# Category percentages for column AccountSid after replacement: AccountSid
# 441377    76.311646
# Others    22.918329
# 0          0.152036
# 1          0.113903
# 2          0.063225
# 3          0.055291
# 4          0.039614
# 5          0.037786
# 7          0.033036
# 6          0.030420
# 8          0.029758
# 11         0.026816
# 9          0.024693
# 12         0.022371
# 15         0.020952
# 14         0.020889
# 17         0.020290
# 18         0.020217
# 16         0.019733
# 19         0.019576
# 21         0.019418
# Name: proportion, dtype: float64
#
# Category percentages for column AccountUpn after replacement: AccountUpn
# 673934    63.598294
# Others    35.039646
# 0          0.152036
# 1          0.099235
# 2          0.089757
# 4          0.081960
# 3          0.081928
# 5          0.079701
# 6          0.078671
# 7          0.078083
# 8          0.076685
# 9          0.075046
# 10         0.074605
# 11         0.072451
# 12         0.072072
# 13         0.063225
# 14         0.049544
# 15         0.044637
# 16         0.039614
# 23         0.026816
# 17         0.025996
# Name: proportion, dtype: float64
#
# Category percentages for column AccountObjectId after replacement: AccountObjectId
# 425863    76.562150
# Others    22.722875
# 0          0.152036
# 1          0.113903
# 2          0.063225
# 3          0.039614
# 5          0.033036
# 4          0.030420
# 6          0.029758
# 9          0.026816
# 7          0.024693
# 10         0.022371
# 13         0.020952
# 12         0.020889
# 15         0.020290
# 16         0.020217
# 14         0.019733
# 17         0.019576
# 19         0.019418
# 18         0.019145
# 20         0.018882
# Name: proportion, dtype: float64
#
# Category percentages for column AccountName after replacement: AccountName
# 453297    75.132736
# Others    24.118854
# 0          0.152036
# 1          0.113903
# 2          0.064181
# 3          0.039625
# 4          0.037786
# 7          0.033036
# 6          0.032416
# 5          0.030420
# 8          0.029758
# 11         0.026816
# 9          0.024693
# 13         0.022371
# 16         0.020952
# 15         0.020889
# 18         0.020290
# 19         0.020217
# 17         0.019733
# 12         0.019649
# 20         0.019639
# Name: proportion, dtype: float64
#
# Category percentages for column DeviceName after replacement: DeviceName
# 153085    92.674131
# Others     6.989255
# 0          0.045982
# 1          0.041442
# 5          0.022623
# 4          0.022613
# 6          0.019744
# 13         0.018147
# 7          0.017138
# 10         0.016234
# 9          0.015961
# 8          0.015888
# 11         0.013492
# 12         0.013145
# 16         0.012473
# 15         0.011506
# 14         0.011495
# 22         0.010728
# 28         0.009793
# 20         0.009667
# 17         0.008543
# Name: proportion, dtype: float64
#
# Category percentages for column NetworkMessageId after replacement: NetworkMessageId
# 529644    87.823276
# Others    12.042762
# 0          0.028718
# 3          0.008932
# 1          0.007744
# 9          0.007355
# 7          0.007355
# 8          0.007355
# 6          0.007334
# 11         0.006977
# 14         0.006305
# 17         0.005779
# 2          0.004970
# 13         0.004960
# 22         0.004728
# 4          0.004413
# 28         0.004340
# 26         0.004235
# 23         0.004203
# 24         0.004203
# 5          0.004056
# Name: proportion, dtype: float64
#
# Category percentages for column EmailClusterId after replacement: EmailClusterId
# Others          86.732017
# 4218786605.0     2.055530
# 4023349548.0     1.966698
# 4140628171.0     1.793166
# 1962111205.0     0.851134
# 2834092745.0     0.614593
# 2122467325.0     0.608396
# 3425846815.0     0.540222
# 2763420209.0     0.538156
# 2681535163.0     0.504070
# 3370906157.0     0.471016
# 2900576879.0     0.437962
# 4143707853.0     0.423501
# 4107518491.0     0.375986
# 2901398217.0     0.360493
# 4274415102.0     0.306780
# 3423486872.0     0.289220
# 3326931161.0     0.287154
# 2136032619.0     0.287154
# 3155166229.0     0.281990
# 4264033966.0     0.274759
# Name: proportion, dtype: float64
#
# Category percentages for column RegistryKey after replacement: RegistryKey
# 1631      99.815863
# 0          0.116383
# Others     0.050080
# 1          0.002574
# 3          0.002469
# 6          0.001482
# 4          0.001429
# 5          0.001377
# 8          0.001240
# 7          0.001030
# 12         0.000788
# 9          0.000736
# 11         0.000694
# 10         0.000694
# 15         0.000609
# 2          0.000557
# 13         0.000462
# 16         0.000420
# 17         0.000378
# 24         0.000378
# 36         0.000357
# Name: proportion, dtype: float64
#
# Category percentages for column RegistryValueName after replacement: RegistryValueName
# 635       99.952926
# Others     0.019219
# 1          0.005075
# 0          0.005075
# 5          0.003268
# 6          0.002690
# 10         0.001187
# 9          0.001177
# 8          0.001156
# 2          0.001114
# 3          0.000799
# 16         0.000788
# 4          0.000767
# 13         0.000736
# 11         0.000683
# 17         0.000620
# 14         0.000588
# 7          0.000578
# 12         0.000567
# 20         0.000525
# 18         0.000462
# Name: proportion, dtype: float64
#
# Category percentages for column RegistryValueData after replacement: RegistryValueData
# 860       99.943195
# Others     0.022507
# 0          0.014679
# 2          0.004760
# 1          0.002911
# 4          0.002228
# 3          0.001744
# 5          0.001503
# 6          0.001313
# 8          0.000799
# 9          0.000736
# 7          0.000588
# 12         0.000420
# 11         0.000410
# 20         0.000389
# 10         0.000357
# 13         0.000336
# 17         0.000305
# 19         0.000284
# 25         0.000273
# 30         0.000263
# Name: proportion, dtype: float64
#
# Category percentages for column ApplicationId after replacement: ApplicationId
# 2251      97.762881
# 0          0.649670
# 1          0.403149
# 2          0.385443
# 3          0.333441
# 4          0.236476
# 5          0.059820
# Others     0.051992
# 6          0.029453
# 7          0.026952
# 8          0.018000
# 9          0.010529
# 10         0.007208
# 11         0.005958
# 12         0.005086
# 13         0.003772
# 14         0.003131
# 15         0.002501
# 16         0.002112
# 17         0.001471
# 19         0.000956
# Name: proportion, dtype: float64
#
# Category percentages for column ApplicationName after replacement: ApplicationName
# 3421      97.696661
# 0          0.650258
# 1          0.403769
# 2          0.385307
# 3          0.333472
# 4          0.236476
# Others     0.096103
# 5          0.069876
# 6          0.029453
# 7          0.027467
# 8          0.020679
# 9          0.010529
# 10         0.007408
# 12         0.006136
# 11         0.005958
# 13         0.005065
# 15         0.003856
# 14         0.003772
# 16         0.003142
# 17         0.002501
# 18         0.002112
# Name: proportion, dtype: float64
#
# Category percentages for column OAuthApplicationId after replacement: OAuthApplicationId
# 881       99.972733
# Others     0.012052
# 0          0.006347
# 1          0.002081
# 2          0.001839
# 3          0.000778
# 4          0.000672
# 5          0.000515
# 6          0.000462
# 7          0.000399
# 8          0.000378
# 9          0.000305
# 10         0.000221
# 11         0.000210
# 12         0.000189
# 13         0.000168
# 15         0.000147
# 16         0.000137
# 14         0.000126
# 17         0.000126
# 19         0.000116
# Name: proportion, dtype: float64
#
# Category percentages for column ThreatFamily after replacement: ThreatFamily
# Phish                        4.708805
# Malgent                      3.520252
# Donoff                       3.364004
# CustomEnterpriseBlock        2.864545
# CustomEnterpriseBlockOnly    2.856532
#                                ...
# AprilAxe                     0.001335
# Kechang                      0.001335
# PolsckiCrypt                 0.001335
# GhostRadmin                  0.001335
# Gootkit                      0.001335
# Name: proportion, Length: 1745, dtype: float64
#
# Category percentages for column FileName after replacement: FileName
# 289573    89.188141
# Others     7.816704
# 0          0.921903
# 1          0.746141
# 2          0.191177
# 3          0.161640
# 4          0.137031
# 5          0.110551
# 6          0.106023
# 9          0.080394
# 8          0.079638
# 7          0.078356
# 10         0.057782
# 11         0.054703
# 12         0.050437
# 13         0.046507
# 14         0.040444
# 16         0.039372
# 17         0.034171
# 15         0.030682
# 19         0.028203
# Name: proportion, dtype: float64
#
# Category percentages for column FolderPath after replacement: FolderPath
# 117668    90.799117
# Others     4.907691
# 0          1.195607
# 1          0.742736
# 2          0.640580
# 3          0.420098
# 4          0.226325
# 5          0.206087
# 6          0.168176
# 8          0.101998
# 7          0.097511
# 9          0.089757
# 10         0.059936
# 13         0.057782
# 12         0.049365
# 14         0.045814
# 15         0.043912
# 18         0.043596
# 16         0.041705
# 19         0.034686
# 17         0.027520
# Name: proportion, dtype: float64
#
# Category percentages for column ResourceIdName after replacement: ResourceIdName
# 3586      99.914194
# Others     0.053295
# 0          0.004098
# 1          0.003457
# 2          0.002879
# 3          0.002658
# 4          0.002585
# 5          0.002490
# 7          0.002165
# 6          0.001954
# 9          0.001660
# 11         0.001608
# 10         0.001061
# 12         0.001019
# 13         0.000893
# 16         0.000778
# 19         0.000662
# 15         0.000651
# 20         0.000641
# 17         0.000630
# 18         0.000620
# Name: proportion, dtype: float64
#
# Category percentages for column ResourceType after replacement: ResourceType
# Virtual Machine                         58.600707
# Key Vault                                6.784452
# App Service                              5.710247
# Azure Arc machine                        5.272085
# Storage Account                          5.173145
# Subscription                             3.830389
# SQL Database                             3.194346
# Azure Database for MySQL Server          2.572438
# Azure Resource                           2.219081
# Virtual Machine Scale Set                1.583039
# API Management Service                   1.328622
# Key Vault Secret                         1.088339
# Azure Database for PostgreSQL Server     0.636042
# SQL Server                               0.579505
# Azure Cosmos DB Account                  0.424028
# Networking                               0.197880
# Synapse SQL Pool                         0.155477
# GCP Compute Instance                     0.141343
# SQL Managed Instance                     0.127208
# Kubernetes Service                       0.127208
# Key Vault Certificate                    0.098940
# AWS EC2 Instance                         0.084806
# Key Vault Key                            0.028269
# Synapse Workspace                        0.028269
# Cognitive Service                        0.014134
# Name: proportion, dtype: float64
#
# Category percentages for column Roles after replacement: Roles
# Contextual        59.833785
# Destination       15.734056
# Suspicious        13.271541
# Attacker           6.003181
# Source             3.287173
# Compromised        1.475583
# PolicyViolator     0.305293
# Attacked           0.086179
# Edited             0.002750
# Added              0.000458
# Name: proportion, dtype: float64
#
# Category percentages for column OSFamily after replacement: OSFamily
# 5    97.958649
# 0     1.996840
# 1     0.028707
# 2     0.015720
# 3     0.000074
# 4     0.000011
# Name: proportion, dtype: float64
#
# Category percentages for column OSVersion after replacement: OSVersion
# 66        97.958723
# 0          1.969194
# 2          0.019881
# 1          0.017359
# 3          0.011821
# 4          0.007692
# 6          0.003804
# 5          0.002795
# Others     0.001492
# 8          0.001387
# 9          0.001145
# 10         0.000935
# 7          0.000851
# 11         0.000694
# 12         0.000567
# 16         0.000399
# 13         0.000336
# 14         0.000326
# 15         0.000231
# 19         0.000189
# 17         0.000179
# Name: proportion, dtype: float64
#
# Category percentages for column AntispamDirection after replacement: AntispamDirection
# Inbound                                               90.868123
# Intraorg                                               8.633856
# Outbound                                               0.489560
# DomainPII_50d8b4a941c26b89482c94ab324b5a274f9ced66     0.005640
# DomainPII_df80ab894e01e375bf55d12ba315c04029d3e32d     0.002820
# Name: proportion, dtype: float64
#
# Category percentages for column SuspicionLevel after replacement: SuspicionLevel
# Suspicious      99.895092
# Incriminated     0.104908
# Name: proportion, dtype: float64
#
# Category percentages for column LastVerdict after replacement: LastVerdict
# Suspicious                                            62.794566
# Malicious                                             19.396043
# NoThreatsFound                                        17.800843
# DomainPII_50d8b4a941c26b89482c94ab324b5a274f9ced66     0.005729
# DomainPII_9207384283ce115db5a590dd9ca5de21e5e99df2     0.002820
# Name: proportion, dtype: float64
#
# Category percentages for column CountryCode after replacement: CountryCode
# 242       92.120018
# 0          1.820122
# Others     1.250079
# 1          1.118082
# 2          0.563958
# 4          0.423407
# 3          0.382543
# 5          0.351629
# 6          0.240384
# 7          0.203040
# 8          0.188445
# 9          0.176435
# 10         0.166547
# 12         0.156092
# 11         0.147402
# 14         0.141507
# 13         0.141307
# 15         0.120565
# 17         0.100727
# 16         0.094464
# 18         0.093245
# Name: proportion, dtype: float64
#
# Category percentages for column State after replacement: State
# 1445      93.348010
# Others     2.759373
# 0          1.091413
# 1          0.423586
# 2          0.303410
# 3          0.242181
# 4          0.201044
# 5          0.165717
# 6          0.163699
# 7          0.152309
# 8          0.131147
# 9          0.127406
# 11         0.125945
# 10         0.121049
# 12         0.121038
# 13         0.102765
# 15         0.098068
# 14         0.097385
# 21         0.076328
# 17         0.075319
# 16         0.072808
# Name: proportion, dtype: float64
#
# Category percentages for column City after replacement: City
# 10630     93.341380
# Others     3.412048
# 0          1.086842
# 1          0.234773
# 2          0.204364
# 3          0.166915
# 4          0.152025
# 5          0.145605
# 6          0.126187
# 7          0.121017
# 8          0.113872
# 9          0.111108
# 12         0.104089
# 10         0.102303
# 11         0.097385
# 13         0.092972
# 14         0.084366
# 15         0.077915
# 16         0.076380
# 23         0.075067
# 18         0.073386
# Name: proportion, dtype: float64
#
# Data types of each column after conversion: Id                    category
# OrgId                 category
# IncidentId            category
# AlertId               category
# Timestamp               object
# DetectorId            category
# AlertTitle            category
# Category                object
# MitreTechniques         object
# IncidentGrade           object
# ActionGrouped           object
# ActionGranular          object
# EntityType              object
# EvidenceRole            object
# DeviceId              category
# Sha256                category
# IpAddress             category
# Url                   category
# AccountSid            category
# AccountUpn            category
# AccountObjectId       category
# AccountName           category
# DeviceName            category
# NetworkMessageId      category
# EmailClusterId        category
# RegistryKey           category
# RegistryValueName     category
# RegistryValueData     category
# ApplicationId         category
# ApplicationName       category
# OAuthApplicationId    category
# ThreatFamily            object
# FileName              category
# FolderPath            category
# ResourceIdName        category
# ResourceType            object
# Roles                   object
# OSFamily              category
# OSVersion             category
# AntispamDirection       object
# SuspicionLevel          object
# LastVerdict             object
# CountryCode           category
# State                 category
# City                  category
# dtype: object

# %%
df['City'].unique()
# Out:
# [3, 10630, 'Others', 9, 14, ..., 10, 5, 13, 12, 4]
# Length: 21
# Categories (21, object): [0, 1, 2, 3, ..., 18, 23, 10630, 'Others']

# %%
import pandas as pd
import numpy as np

def preprocess_data(df, output_file_path, missing_threshold=0.5):
    try:
        # Load the DataFrame
        print(f"Loaded data with {df.shape[0]} rows and {df.shape[1]} columns.")

        # Drop columns with high missing values
        missing_percentages = df.isnull().mean()
        columns_to_drop = missing_percentages[missing_percentages > missing_threshold].index
        df.drop(columns=columns_to_drop, inplace=True)
        print(f"Columns dropped due to more than {missing_threshold * 100}% missing values: {columns_to_drop.tolist()}")

        # Remove duplicates
        df.drop_duplicates(inplace=True)
        print(f"Duplicates removed. Number of rows after deduplication: {df.shape[0]}")

        # Feature extraction from 'Timestamp'
        if 'Timestamp' in df.columns:
            df['Timestamp'] = pd.to_datetime(df['Timestamp'], errors='coerce')
            df['Year'] = df['Timestamp'].dt.year
            df['Month'] = df['Timestamp'].dt.month
            df['DayOfWeek'] = df['Timestamp'].dt.dayofweek
            df['Hour'] = df['Timestamp'].dt.hour
            df.drop(columns=['Timestamp'], inplace=True)
            print("Timestamp features extracted.")

        # Fill missing values in specific columns with their mode
        for column in ['CountryCode', 'State', 'City']:
            if column in df.columns:
                mode_value = df[column].mode()[0]
                df[column].fillna(mode_value, inplace=True)
                print(f"Filled missing values in '{column}' with mode: {mode_value}")

        # Fill missing values in 'IncidentGrade' equally
        if 'IncidentGrade' in df.columns:
            # Calculate and print the original value counts
            original_value_counts = df['IncidentGrade'].value_counts()
            print("Original value counts before filling missing values:")
            print(original_value_counts)

            # Identify unique values in the IncidentGrade column
            unique_values = df['IncidentGrade'].dropna().unique()

            # Count the number of missing values
            num_missing = df['IncidentGrade'].isnull().sum()

            # Create a list of values to fill the missing values equally
            fill_values = []
            for value in unique_values:
                fill_values.extend([value] * (num_missing // len(unique_values)))

            # If there are any remaining missing values, distribute them
            remaining = num_missing % len(unique_values)
            fill_values.extend(np.random.choice(unique_values, remaining))

            # Shuffle the fill_values list to randomize the distribution
            np.random.shuffle(fill_values)

            # Fill the missing values with the prepared list
            df.loc[df['IncidentGrade'].isnull(), 'IncidentGrade'] = fill_values

            # Calculate and print the value counts after filling the missing values
            filled_value_counts = df['IncidentGrade'].value_counts()
            print("\nValue counts after filling missing values:")
            print(filled_value_counts)

        # Convert all columns to 'category' dtype
        df = df.astype('category')

        # Save the preprocessed DataFrame
        df.to_csv(output_file_path, index=False)
        print(f"Preprocessed data saved to {output_file_path}.")

    except Exception as e:
        print(f"An error occurred: {e}")


output_file_path = r"./data/preprocessed_data_1.csv"

# Run the preprocessing function
preprocess_data(df, output_file_path)
# Out:
# Loaded data with 9516837 rows and 45 columns.
# Columns dropped due to more than 50.0% missing values: ['MitreTechniques', 'ActionGrouped', 'ActionGranular', 'EmailClusterId', 'ThreatFamily', 'ResourceType', 'Roles', 'AntispamDirection', 'SuspicionLevel', 'LastVerdict']
# Duplicates removed. Number of rows after deduplication: 4430709
# Timestamp features extracted.
# Filled missing values in 'CountryCode' with mode: 242
# Filled missing values in 'State' with mode: 1445
# Filled missing values in 'City' with mode: 10630
# Original value counts before filling missing values:
# IncidentGrade
# TruePositive      1900560
# BenignPositive    1623631
# FalsePositive      887877
# Name: count, dtype: int64
#
# Value counts after filling missing values:
# IncidentGrade
# TruePositive      1906774
# BenignPositive    1629844
# FalsePositive      894091
# Name: count, dtype: int64
# Preprocessed data saved to ./data/preprocessed_data_1.csv.

# %%
df.shape
# Out:
# (4430709, 38)

# %%
df.head()
# Out:
#        Id   OrgId IncidentId AlertId DetectorId AlertTitle           Category  \
# 0  Others       0     Others  Others          7          6      InitialAccess
# 1  Others  Others     Others  Others     Others     Others       Exfiltration
# 2  Others  Others     Others  Others     Others     Others      InitialAccess
# 3  Others  Others     Others  Others          2          2  CommandAndControl
# 4  Others  Others     Others  Others          9     Others          Execution
#
#     IncidentGrade EntityType EvidenceRole DeviceId  Sha256 IpAddress     Url  \
# 0    TruePositive         Ip      Related    98799  138268    Others  160396
# 1   FalsePositive       User     Impacted    98799  138268    360606  160396
# 2   FalsePositive        Url      Related    98799  138268    360606  Others
# 3  BenignPositive        Url      Related    98799  138268    360606      13
# 4    TruePositive       User     Impacted    98799  138268    360606  160396
#
#   AccountSid AccountUpn AccountObjectId AccountName DeviceName  \
# 0     441377     673934          425863      453297     153085
# 1     Others     Others          Others      Others     153085
# 2     441377     673934          425863      453297     153085
# 3     441377     673934          425863      453297     153085
# 4     Others     Others          Others      Others     153085
#
#   NetworkMessageId RegistryKey RegistryValueName RegistryValueData  \
# 0           529644        1631               635               860
# 1           529644        1631               635               860
# 2           529644        1631               635               860
# 3           529644        1631               635               860
# 4           529644        1631               635               860
#
#   ApplicationId ApplicationName OAuthApplicationId FileName FolderPath  \
# 0          2251            3421                881   289573     117668
# 1          2251            3421                881   289573     117668
# 2          2251            3421                881   289573     117668
# 3          2251            3421                881   289573     117668
# 4          2251            3421                881   289573     117668
#
#   ResourceIdName OSFamily OSVersion CountryCode State   City  Year  Month  \
# 0           3586        5        66      Others     6      3  2024      6
# 1           3586        5        66         242  1445  10630  2024      6
# 2           3586        5        66         242  1445  10630  2024      6
# 3           3586        5        66         242  1445  10630  2024      6
# 4           3586        5        66         242  1445  10630  2024      6
#
#    DayOfWeek  Hour
# 0          1     6
# 1          4     3
# 2          3     4
# 3          0    16
# 4          5     1

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# Define file paths
input_file_path = r"./data/preprocessed_data_1.csv"
output_file_path = r"./data/top_n_categories_1.csv"
top_n_categories = 5  # Number of top categories to retain

# Read the CSV file
try:
    df = pd.read_csv(input_file_path)
except FileNotFoundError:
    print(f"Error: The file at {input_file_path} was not found.")
    raise
except pd.errors.EmptyDataError:
    print("Error: The file is empty.")
    raise

# Display initial columns to verify the read operation
print("Initial columns in the DataFrame:")
print(df.columns.tolist())

# Columns to be dropped
columns_to_drop = [
    'Id', 'IncidentId', 'AlertId', 'DeviceId', 'Sha256', 'IpAddress', 'Url',
    'AccountSid', 'AccountUpn', 'AccountObjectId', 'AccountName', 'DeviceName',
    'NetworkMessageId', 'RegistryKey', 'RegistryValueName', 'RegistryValueData',
    'ApplicationId', 'OAuthApplicationId', 'FileName', 'FolderPath', 'ResourceIdName'
]

# Check if the columns to drop are in the DataFrame
columns_to_drop = [col for col in columns_to_drop if col in df.columns]

# Removing specified columns
df = df.drop(columns=columns_to_drop)

# Display columns after dropping to verify the drop operation
print("Columns after dropping:", df.columns.tolist())

# Convert only non-object columns to 'category' dtype, leave object columns unchanged
df[df.select_dtypes(exclude='object').columns] = df.select_dtypes(exclude='object').astype('category')

# Replace rare categories with 'Other'
def replace_rare_categories(df, top_n=15, replace_name='other'):
    for col in df.select_dtypes(include=['category']).columns:
        top_categories = df[col].value_counts().nlargest(top_n).index
        df[col] = df[col].apply(lambda x: x if x in top_categories else replace_name)
        df[col] = df[col].astype('category')

replace_rare_categories(df, top_n=top_n_categories)

# Save the preprocessed DataFrame
try:
    df.to_csv(output_file_path, index=False)
    print(f"Processed data saved to {output_file_path}.")
except Exception as e:
    print(f"Error saving file: {e}")
    raise

# Display the processed DataFrame
print("\nProcessed DataFrame:")
print(df.head())
print(f"Shape of processed DataFrame: {df.shape}")

# Check for missing values
print("\nMissing values:", df.isnull().sum())

# Display data types of each column
print("\nData types of each column:", df.dtypes)

# Display the number of unique categories for each column
print("\nNumber of unique categories per column:")
for col in df.select_dtypes(include=['category']).columns:
    num_unique_categories = df[col].nunique()
    print(f"{col}: {num_unique_categories}")

# Optionally, display the number of unique values for non-categorical columns
print("\nNumber of unique values per non-categorical column:")
for col in df.select_dtypes(exclude=['category']).columns:
    num_unique_values = df[col].nunique()
    print(f"{col}: {num_unique_values}")
# Out:
# Initial columns in the DataFrame:
# ['Id', 'OrgId', 'IncidentId', 'AlertId', 'DetectorId', 'AlertTitle', 'Category', 'IncidentGrade', 'EntityType', 'EvidenceRole', 'DeviceId', 'Sha256', 'IpAddress', 'Url', 'AccountSid', 'AccountUpn', 'AccountObjectId', 'AccountName', 'DeviceName', 'NetworkMessageId', 'RegistryKey', 'RegistryValueName', 'RegistryValueData', 'ApplicationId', 'ApplicationName', 'OAuthApplicationId', 'FileName', 'FolderPath', 'ResourceIdName', 'OSFamily', 'OSVersion', 'CountryCode', 'State', 'City', 'Year', 'Month', 'DayOfWeek', 'Hour']
# Columns after dropping: ['OrgId', 'DetectorId', 'AlertTitle', 'Category', 'IncidentGrade', 'EntityType', 'EvidenceRole', 'ApplicationName', 'OSFamily', 'OSVersion', 'CountryCode', 'State', 'City', 'Year', 'Month', 'DayOfWeek', 'Hour']
# Processed data saved to ./data/top_n_categories_1.csv.
#
# Processed DataFrame:
#     OrgId DetectorId AlertTitle           Category   IncidentGrade EntityType  \
# 0       0          7          6      InitialAccess    TruePositive         Ip
# 1  Others     Others     Others       Exfiltration   FalsePositive       User
# 2  Others     Others     Others      InitialAccess   FalsePositive        Url
# 3  Others          2          2  CommandAndControl  BenignPositive        Url
# 4  Others          9     Others          Execution    TruePositive       User
#
#   EvidenceRole ApplicationName OSFamily OSVersion CountryCode State   City  \
# 0      Related            3421        5        66      Others     6      3
# 1     Impacted            3421        5        66         242  1445  10630
# 2      Related            3421        5        66         242  1445  10630
# 3      Related            3421        5        66         242  1445  10630
# 4     Impacted            3421        5        66         242  1445  10630
#
#    Year Month DayOfWeek   Hour
# 0  2024     6         1  other
# 1  2024     6         4  other
# 2  2024     6         3  other
# 3  2024     6         0     16
# 4  2024     6     other  other
# Shape of processed DataFrame: (4430709, 17)
#
# Missing values: OrgId              0
# DetectorId         0
# AlertTitle         0
# Category           0
# IncidentGrade      0
# EntityType         0
# EvidenceRole       0
# ApplicationName    0
# OSFamily           0
# OSVersion          0
# CountryCode        0
# State              0
# City               0
# Year               0
# Month              0
# DayOfWeek          0
# Hour               0
# dtype: int64
#
# Data types of each column: OrgId                object
# DetectorId           object
# AlertTitle           object
# Category             object
# IncidentGrade        object
# EntityType           object
# EvidenceRole         object
# ApplicationName      object
# OSFamily           category
# OSVersion            object
# CountryCode          object
# State                object
# City                 object
# Year               category
# Month              category
# DayOfWeek          category
# Hour               category
# dtype: object
#
# Number of unique categories per column:
# OSFamily: 6
# Year: 2
# Month: 6
# DayOfWeek: 6
# Hour: 6
#
# Number of unique values per non-categorical column:
# OrgId: 21
# DetectorId: 21
# AlertTitle: 21
# Category: 20
# IncidentGrade: 3
# EntityType: 33
# EvidenceRole: 2
# ApplicationName: 21
# OSVersion: 41
# CountryCode: 21
# State: 21
# City: 21

# %%
import pandas as pd

# Read the CSV file
file_path = r"./data/top_n_categories_1.csv"
df = pd.read_csv(file_path)

# Display initial DataFrame
print("Initial DataFrame:", df.head())

# Function to identify and remove outliers
def identify_and_remove_outliers(df):
    outlier_indices = []
    for col in df.select_dtypes(include=[float, int]).columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
        outlier_indices.extend(outliers.index.tolist())
    
    outlier_indices = list(set(outlier_indices))
    outlier_rows = df.loc[outlier_indices]
    df_cleaned = df.drop(outlier_indices)
    
    return df_cleaned, outlier_rows

# Identify and remove outliers
df_cleaned, outlier_rows = identify_and_remove_outliers(df)

# Print the rows identified as outliers
print("\nRows identified as outliers:", outlier_rows)

# Print the cleaned DataFrame
print("\nCleaned DataFrame:", df_cleaned.head())

# Print the rows after removing outliers
print("\nRows after removing outliers:", df_cleaned)

# Save the cleaned DataFrame to a new CSV file
output_file_path = r"./data/top_n_categories_cleaned_1.csv"
df_cleaned.to_csv(output_file_path, index=False)
print(f"\nCleaned data saved to {output_file_path}")
# Out:
# Initial DataFrame:     OrgId DetectorId AlertTitle           Category   IncidentGrade EntityType  \
# 0       0          7          6      InitialAccess    TruePositive         Ip
# 1  Others     Others     Others       Exfiltration   FalsePositive       User
# 2  Others     Others     Others      InitialAccess   FalsePositive        Url
# 3  Others          2          2  CommandAndControl  BenignPositive        Url
# 4  Others          9     Others          Execution    TruePositive       User
#
#   EvidenceRole ApplicationName OSFamily OSVersion CountryCode State   City  \
# 0      Related            3421        5        66      Others     6      3
# 1     Impacted            3421        5        66         242  1445  10630
# 2      Related            3421        5        66         242  1445  10630
# 3      Related            3421        5        66         242  1445  10630
# 4     Impacted            3421        5        66         242  1445  10630
#
#    Year Month DayOfWeek   Hour
# 0  2024     6         1  other
# 1  2024     6         4  other
# 2  2024     6         3  other
# 3  2024     6         0     16
# 4  2024     6     other  other
#
# Rows identified as outliers:           OrgId DetectorId AlertTitle       Category   IncidentGrade  \
# 4121090  Others     Others     Others  InitialAccess  BenignPositive
# 2481159  Others          0          0  InitialAccess    TruePositive
# 3893255  Others          0          0  InitialAccess    TruePositive
# 2519052  Others          0          0  InitialAccess    TruePositive
# 859670   Others          0          0  InitialAccess    TruePositive
# ...         ...        ...        ...            ...             ...
# 4220400  Others          4          3  InitialAccess    TruePositive
# 1729015  Others     Others     Others  InitialAccess  BenignPositive
# 4366328  Others          0          0  InitialAccess    TruePositive
# 2161658  Others         19         15  InitialAccess    TruePositive
# 3649022  Others     Others     Others  InitialAccess  BenignPositive
#
#                 EntityType EvidenceRole ApplicationName OSFamily OSVersion  \
# 4121090            Mailbox     Impacted            3421        5        66
# 2481159  CloudLogonSession      Related            3421        5        66
# 3893255               User     Impacted            3421        5        66
# 2519052               User     Impacted            3421        5        66
# 859670                User     Impacted            3421        5        66
# ...                    ...          ...             ...      ...       ...
# 4220400  CloudLogonRequest      Related            3421        5        66
# 1729015            Mailbox     Impacted            3421        5        66
# 4366328  CloudLogonRequest      Related            3421        5        66
# 2161658  CloudLogonRequest      Related            3421        5        66
# 3649022            Mailbox     Impacted            3421        5        66
#
#         CountryCode State   City  Year  Month DayOfWeek   Hour
# 4121090         242  1445  10630  2023  other         3  other
# 2481159         242  1445  10630  2023  other         4     14
# 3893255         242  1445  10630  2023  other     other  other
# 2519052         242  1445  10630  2023  other         2     14
# 859670          242  1445  10630  2023  other         1  other
# ...             ...   ...    ...   ...    ...       ...    ...
# 4220400         242  1445  10630  2023  other         3  other
# 1729015         242  1445  10630  2023  other         1  other
# 4366328         242  1445  10630  2023  other         3     14
# 2161658         242  1445  10630  2023  other         3  other
# 3649022         242  1445  10630  2023  other         3  other
#
# [179 rows x 17 columns]
#
# Cleaned DataFrame:     OrgId DetectorId AlertTitle           Category   IncidentGrade EntityType  \
# 0       0          7          6      InitialAccess    TruePositive         Ip
# 1  Others     Others     Others       Exfiltration   FalsePositive       User
# 2  Others     Others     Others      InitialAccess   FalsePositive        Url
# 3  Others          2          2  CommandAndControl  BenignPositive        Url
# 4  Others          9     Others          Execution    TruePositive       User
#
#   EvidenceRole ApplicationName OSFamily OSVersion CountryCode State   City  \
# 0      Related            3421        5        66      Others     6      3
# 1     Impacted            3421        5        66         242  1445  10630
# 2      Related            3421        5        66         242  1445  10630
# 3      Related            3421        5        66         242  1445  10630
# 4     Impacted            3421        5        66         242  1445  10630
#
#    Year Month DayOfWeek   Hour
# 0  2024     6         1  other
# 1  2024     6         4  other
# 2  2024     6         3  other
# 3  2024     6         0     16
# 4  2024     6     other  other
#
# Rows after removing outliers:           OrgId DetectorId AlertTitle           Category   IncidentGrade  \
# 0             0          7          6      InitialAccess    TruePositive
# 1        Others     Others     Others       Exfiltration   FalsePositive
# 2        Others     Others     Others      InitialAccess   FalsePositive
# 3        Others          2          2  CommandAndControl  BenignPositive
# 4        Others          9     Others          Execution    TruePositive
# ...         ...        ...        ...                ...             ...
# 4430704  Others     Others     Others       Exfiltration   FalsePositive
# 4430705       5          4          3      InitialAccess    TruePositive
# 4430706  Others     Others     Others      InitialAccess  BenignPositive
# 4430707  Others         19         15      InitialAccess   FalsePositive
# 4430708  Others          0          0      InitialAccess    TruePositive
#
#           EntityType EvidenceRole ApplicationName OSFamily OSVersion  \
# 0                 Ip      Related            3421        5        66
# 1               User     Impacted            3421        5        66
# 2                Url      Related            3421        5        66
# 3                Url      Related            3421        5        66
# 4               User     Impacted            3421        5        66
# ...              ...          ...             ...      ...       ...
# 4430704         File     Impacted            3421        5        66
# 4430705           Ip      Related            3421        5        66
# 4430706  MailMessage      Related            3421        5        66
# 4430707           Ip      Related            3421        5        66
# 4430708           Ip      Related            3421        5        66
#
#         CountryCode State    City  Year Month DayOfWeek   Hour
# 0            Others     6       3  2024     6         1  other
# 1               242  1445   10630  2024     6         4  other
# 2               242  1445   10630  2024     6         3  other
# 3               242  1445   10630  2024     6         0     16
# 4               242  1445   10630  2024     6     other  other
# ...             ...   ...     ...   ...   ...       ...    ...
# 4430704         242  1445   10630  2024     6         0     16
# 4430705           3     5  Others  2024     6         2     16
# 4430706         242  1445   10630  2024     6         4  other
# 4430707           0     3      15  2024     6         2     16
# 4430708           1     0       0  2024     6     other  other
#
# [4430530 rows x 17 columns]
#
# Cleaned data saved to ./data/top_n_categories_cleaned_1.csv

# %%
df.shape
# Out:
# (4430709, 17)

# %%
import pandas as pd

# Define file paths
input_file_path =  r"./data/top_n_categories_cleaned_1.csv"
output_file_path = r"./data/top_n_categories_encoded_1.csv"

# Define the number of top categories to retain and the replacement value for others
top_n_categories = 5
replacement_value = 6

# Function to encode top categories and replace others
def encode_categories(df, top_n=5, replacement_val=6):
    # Convert all integer columns to categorical
    for col in df.select_dtypes(include=['int64', 'float64']).columns:
        df[col] = df[col].astype('category')
    
    # Apply the encoding to each categorical column
    for col in df.select_dtypes(include=['category', 'object']).columns:
        # Convert to category type if not already
        df[col] = df[col].astype('category')
        category_counts = df[col].value_counts()
        top_categories = list(category_counts.nlargest(top_n).index)
        
        # Add 'Other' to the list of categories if not already present
        if 'Other' not in top_categories:
            top_categories.append('Other')
        
        # Ensure all categories are strings for consistent sorting and mapping
        top_categories = [str(cat) for cat in top_categories]
        
        # Create a manual mapping for label encoding, ensuring continuous integers
        unique_categories = sorted(top_categories)
        if 'Other' in unique_categories:
            unique_categories.remove('Other')
            unique_categories.append('Other')
        
        # Create the manual mapping
        manual_mapping = {category: i for i, category in enumerate(unique_categories)}
        
        # Add 'Other' to the Categorical type
        df[col] = df[col].cat.add_categories(['Other'])
        
        # Replace categories not in top_n with 'Other'
        df[col] = df[col].apply(lambda x: str(x) if str(x) in top_categories else 'Other')
        
        # Apply manual label encoding
        df[col] = df[col].map(manual_mapping)
        
        # Fill NaN values with the replacement value
        df[col] = df[col].fillna(manual_mapping['Other']).astype(int)
    
    return df

# Process the CSV file in chunks
chunk_size = 500000  # Adjust the chunk size as needed
chunks = []

for chunk in pd.read_csv(input_file_path, chunksize=chunk_size, low_memory=False):
    chunk_encoded = encode_categories(chunk, top_n=top_n_categories, replacement_val=replacement_value)
    chunks.append(chunk_encoded)

# Concatenate all chunks
df_encoded = pd.concat(chunks, axis=0)

# Save the processed DataFrame with encoded categories
df_encoded.to_csv(output_file_path, index=False)

# Display the processed DataFrame
print("\nProcessed DataFrame with encoded categories:")
print(df_encoded.head())
print(f"Shape of processed DataFrame: {df_encoded.shape}")

# Display the number of unique values per column after encoding
print("\nNumber of unique values per column after encoding:")
for col in df_encoded.columns:
    num_unique_values = df_encoded[col].nunique()
    print(f"{col}: {num_unique_values}")

# Check unique values in 'IncidentGrade'
unique_values = df_encoded['IncidentGrade'].unique()
print("\nUnique values in 'IncidentGrade':", unique_values)
# Out:
# Processed DataFrame with encoded categories:
#    OrgId  DetectorId  AlertTitle  Category  IncidentGrade  EntityType  \
# 0      0           5           5         3              2           1
# 1      4           4           4         2              1           4
# 2      4           4           4         3              1           3
# 3      4           2           2         0              0           3
# 4      4           5           4         1              2           4
#
#    EvidenceRole  ApplicationName  OSFamily  OSVersion  CountryCode  State  \
# 0             1                4         3          4            4      5
# 1             0                4         3          4            3      2
# 2             1                4         3          4            3      2
# 3             1                4         3          4            3      2
# 4             0                4         3          4            3      2
#
#    City  Year  Month  DayOfWeek  Hour
# 0     5     0      3          1     4
# 1     2     0      3          5     4
# 2     2     0      3          3     4
# 3     2     0      3          0     1
# 4     2     0      3          4     4
# Shape of processed DataFrame: (4430530, 17)
#
# Number of unique values per column after encoding:
# OrgId: 6
# DetectorId: 6
# AlertTitle: 6
# Category: 6
# IncidentGrade: 3
# EntityType: 6
# EvidenceRole: 2
# ApplicationName: 6
# OSFamily: 6
# OSVersion: 6
# CountryCode: 6
# State: 6
# City: 6
# Year: 1
# Month: 6
# DayOfWeek: 6
# Hour: 6
#
# Unique values in 'IncidentGrade': [2 1 0]

# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest, chi2

# Read the CSV file
file_path = r"./data/top_n_categories_encoded_1.csv"
df = pd.read_csv(file_path)

# Define the features (X) and the target (y)
X = df.drop(columns=['IncidentGrade'])
y = df['IncidentGrade']

# Perform Chi-Square test
chi2_selector = SelectKBest(chi2, k='all')
chi2_selector.fit(X, y)

# Create DataFrame to view scores and p-values
chi2_scores = pd.DataFrame({
    'Feature': X.columns,
    'Chi2 Score': chi2_selector.scores_,
    'P-value': chi2_selector.pvalues_
})

# Sort by Chi2 Score
chi2_scores = chi2_scores.sort_values(by='Chi2 Score', ascending=False)

# Print Chi2 Scores and P-values
print(chi2_scores)

# Select features based on Chi-Square p-values
selected_features_chi = chi2_scores[chi2_scores['P-value'] < 0.05]['Feature'].tolist()
print("Selected Features:", selected_features_chi)

# Create a DataFrame with the selected features and include the target variable
df_selected_features = df[selected_features_chi + ['IncidentGrade']]

# Save the selected features to a new CSV file
output_file_path = r"./data/selected_features_training_1.csv"
df_selected_features.to_csv(output_file_path, index=False)
print(f"Selected features saved to {output_file_path}")
# Out:
#             Feature     Chi2 Score        P-value
# 0             OrgId  604384.907618   0.000000e+00
# 2        AlertTitle  433061.654489   0.000000e+00
# 4        EntityType  390382.481263   0.000000e+00
# 1        DetectorId  266139.745056   0.000000e+00
# 3          Category   87649.192025   0.000000e+00
# 5      EvidenceRole   50284.952490   0.000000e+00
# 11             City   31123.093688   0.000000e+00
# 10            State   26795.935348   0.000000e+00
# 7          OSFamily   10053.268344   0.000000e+00
# 8         OSVersion    9086.846630   0.000000e+00
# 15             Hour    2947.383025   0.000000e+00
# 9       CountryCode    1779.296746   0.000000e+00
# 14        DayOfWeek     869.376167  1.649544e-189
# 13            Month     220.757970   1.156155e-48
# 6   ApplicationName     192.473710   1.602747e-42
# 12             Year            NaN            NaN
# Selected Features: ['OrgId', 'AlertTitle', 'EntityType', 'DetectorId', 'Category', 'EvidenceRole', 'City', 'State', 'OSFamily', 'OSVersion', 'Hour', 'CountryCode', 'DayOfWeek', 'Month', 'ApplicationName']
# Selected features saved to ./data/selected_features_training_1.csv

# %%
import pandas as pd
import numpy as np

# Define functions
def drop_usage_column(df):
    if 'Usage' in df.columns:
        df.drop(columns=['Usage'], inplace=True)
        print("Dropped 'Usage' column.")
    else:
        print("'Usage' column not found in the dataset.")
    return df

def drop_high_missing_values(df, threshold=0.5):
    missing_percentages = df.isnull().mean()
    columns_to_drop = missing_percentages[missing_percentages > threshold].index
    df.drop(columns=columns_to_drop, inplace=True)
    print(f"Columns dropped due to more than {threshold * 100}% missing values: {columns_to_drop.tolist()}")
    return df

def remove_duplicates(df):
    df.drop_duplicates(inplace=True)
    print(f"Duplicates removed. Number of rows after deduplication: {df.shape[0]}")
    return df

def extract_features(df):
    if 'Timestamp' in df.columns:
        df['Timestamp'] = pd.to_datetime(df['Timestamp'], errors='coerce')
        df['Year'] = df['Timestamp'].dt.year
        df['Month'] = df['Timestamp'].dt.month
        df['DayOfWeek'] = df['Timestamp'].dt.dayofweek
        df['Hour'] = df['Timestamp'].dt.hour
        df.drop(columns=['Timestamp'], inplace=True)
        print("Timestamp features extracted.")
    return df

def convert_to_category(df):
    return df.astype('category')

def replace_rare_categories(df, top_n=5, replace_name='other'):
    for col in df.select_dtypes(include=['category']).columns:
        top_categories = df[col].value_counts().nlargest(top_n).index
        df[col] = df[col].apply(lambda x: x if x in top_categories else replace_name)
        df[col] = df[col].astype('category')
    print(f"Replaced rare categories in each column with '{replace_name}'.")

def identify_and_remove_outliers(df):
    outlier_indices = []
    for col in df.select_dtypes(include=[float, int]).columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
        outlier_indices.extend(outliers.index.tolist())
    
    outlier_indices = list(set(outlier_indices))
    outlier_rows = df.loc[outlier_indices]
    df_cleaned = df.drop(outlier_indices)
    
    return df_cleaned, outlier_rows

# Load data
file_path = r"./data/GUIDE_Test.csv"
try:
    df = pd.read_csv(file_path)
    print(f"Loaded data with {df.shape[0]} rows and {df.shape[1]} columns.")
except FileNotFoundError:
    print(f"Error: The file at {file_path} was not found.")
    raise
except pd.errors.EmptyDataError:
    print("Error: The file is empty.")
    raise

# Step 1: Drop 'Usage' column
df = drop_usage_column(df)

# Step 2: Drop columns with high missing values
df = drop_high_missing_values(df)

# Step 3: Remove duplicate rows
df = remove_duplicates(df)

# Step 4: Extract features from 'Timestamp' column
df = extract_features(df)

# Step 5: Drop specified columns
columns_to_drop = [
    'Id', 'IncidentId', 'AlertId', 'DeviceId', 'Sha256', 'IpAddress', 'Url',
    'AccountSid', 'AccountUpn', 'AccountObjectId', 'AccountName', 'DeviceName',
    'NetworkMessageId', 'RegistryKey', 'RegistryValueName', 'RegistryValueData',
    'ApplicationId', 'OAuthApplicationId', 'FileName', 'FolderPath', 'ResourceIdName'
]
df.drop(columns=columns_to_drop, inplace=True, errors='ignore')
print(f"Dropped columns: {columns_to_drop}")

# Step 6: Convert all columns to 'category' dtype
df = convert_to_category(df)
print("Converted all columns to 'category' dtype.")

# Step 7: Replace rare categories
top_n_categories = 5  # Adjust the number of top categories as needed
replace_rare_categories(df, top_n=top_n_categories)

# Step 8: Identify and remove outliers
# Print the DataFrame before removing outliers
print("\nDataFrame before removing outliers:", df.head())

df_cleaned, outlier_rows = identify_and_remove_outliers(df)

# Step 9: Print the rows identified as outliers
print("\nRows identified as outliers:", outlier_rows)

# Print the DataFrame after removing outliers
print("\nDataFrame after removing outliers:", df_cleaned.head())

# Step 10: Save the cleaned DataFrame to a new CSV file
output_file_path = r"./data/top_n_categories_cleaned_testing_1.csv"
df_cleaned.to_csv(output_file_path, index=False)
print(f"\nCleaned data saved to {output_file_path}")
# Out:
# Loaded data with 4147992 rows and 46 columns.
# Dropped 'Usage' column.
# Columns dropped due to more than 50.0% missing values: ['MitreTechniques', 'ActionGrouped', 'ActionGranular', 'EmailClusterId', 'ThreatFamily', 'ResourceType', 'Roles', 'AntispamDirection', 'SuspicionLevel', 'LastVerdict']
# Duplicates removed. Number of rows after deduplication: 3922695
# Timestamp features extracted.
# Dropped columns: ['Id', 'IncidentId', 'AlertId', 'DeviceId', 'Sha256', 'IpAddress', 'Url', 'AccountSid', 'AccountUpn', 'AccountObjectId', 'AccountName', 'DeviceName', 'NetworkMessageId', 'RegistryKey', 'RegistryValueName', 'RegistryValueData', 'ApplicationId', 'OAuthApplicationId', 'FileName', 'FolderPath', 'ResourceIdName']
# Converted all columns to 'category' dtype.
# Replaced rare categories in each column with 'other'.
#
# DataFrame before removing outliers:    OrgId DetectorId AlertTitle           Category   IncidentGrade EntityType  \
# 0  other      other      other              other  BenignPositive       User
# 1      3          2          2  CommandAndControl  BenignPositive    Machine
# 2  other      other      other              other  BenignPositive      other
# 3  other          0          0      InitialAccess   FalsePositive      other
# 4  other      other      other              other  BenignPositive       User
#
#   EvidenceRole ApplicationName OSFamily OSVersion CountryCode State   City  \
# 0     Impacted            3421        5        66         242  1445  10630
# 1     Impacted            3421        0         0         242  1445  10630
# 2      Related            3421        5        66         242  1445  10630
# 3      Related            3421        5        66         242  1445  10630
# 4     Impacted            3421        5        66         242  1445  10630
#
#    Year Month DayOfWeek   Hour
# 0  2024     6         1  other
# 1  2024     6         0  other
# 2  2024     6     other  other
# 3  2024     6         2  other
# 4  2024     6         3     17
#
# Rows identified as outliers: Empty DataFrame
# Columns: [OrgId, DetectorId, AlertTitle, Category, IncidentGrade, EntityType, EvidenceRole, ApplicationName, OSFamily, OSVersion, CountryCode, State, City, Year, Month, DayOfWeek, Hour]
# Index: []
#
# DataFrame after removing outliers:    OrgId DetectorId AlertTitle           Category   IncidentGrade EntityType  \
# 0  other      other      other              other  BenignPositive       User
# 1      3          2          2  CommandAndControl  BenignPositive    Machine
# 2  other      other      other              other  BenignPositive      other
# 3  other          0          0      InitialAccess   FalsePositive      other
# 4  other      other      other              other  BenignPositive       User
#
#   EvidenceRole ApplicationName OSFamily OSVersion CountryCode State   City  \
# 0     Impacted            3421        5        66         242  1445  10630
# 1     Impacted            3421        0         0         242  1445  10630
# 2      Related            3421        5        66         242  1445  10630
# 3      Related            3421        5        66         242  1445  10630
# 4     Impacted            3421        5        66         242  1445  10630
#
#    Year Month DayOfWeek   Hour
# 0  2024     6         1  other
# 1  2024     6         0  other
# 2  2024     6     other  other
# 3  2024     6         2  other
# 4  2024     6         3     17
#
# Cleaned data saved to ./data/top_n_categories_cleaned_testing_1.csv

# %%
import pandas as pd

# Define file paths
input_file_path =r"./data/top_n_categories_cleaned_testing_1.csv"
output_file_path = r"./data/top_n_categories_encoded_testing.csv"

# Define the number of top categories to retain and the replacement value for others
top_n_categories = 5
replacement_value = 6

# Function to encode top categories and replace others
def encode_categories(df, top_n=5, replacement_val=6):
    # Convert all integer columns to categorical
    for col in df.select_dtypes(include=['int64', 'float64']).columns:
        df[col] = df[col].astype('category')
    
    # Apply the encoding to each categorical column
    for col in df.select_dtypes(include=['category', 'object']).columns:
        # Convert to category type if not already
        df[col] = df[col].astype('category')
        category_counts = df[col].value_counts()
        top_categories = list(category_counts.nlargest(top_n).index)
        
        # Add 'Other' to the list of categories if not already present
        if 'Other' not in top_categories:
            top_categories.append('Other')
        
        # Ensure all categories are strings for consistent sorting and mapping
        top_categories = [str(cat) for cat in top_categories]
        
        # Create a manual mapping for label encoding, ensuring continuous integers
        unique_categories = sorted(top_categories)
        if 'Other' in unique_categories:
            unique_categories.remove('Other')
            unique_categories.append('Other')
        
        # Create the manual mapping
        manual_mapping = {category: i for i, category in enumerate(unique_categories)}
        
        # Add 'Other' to the Categorical type
        df[col] = df[col].cat.add_categories(['Other'])
        
        # Replace categories not in top_n with 'Other'
        df[col] = df[col].apply(lambda x: str(x) if str(x) in top_categories else 'Other')
        
        # Apply manual label encoding
        df[col] = df[col].map(manual_mapping)
        
        # Fill NaN values with the replacement value
        df[col] = df[col].fillna(manual_mapping['Other']).astype(int)
    
    return df

# Process the CSV file in chunks
chunk_size = 500000  # Adjust the chunk size as needed
chunks = []

for chunk in pd.read_csv(input_file_path, chunksize=chunk_size, low_memory=False):
    chunk_encoded = encode_categories(chunk, top_n=top_n_categories, replacement_val=replacement_value)
    chunks.append(chunk_encoded)

# Concatenate all chunks
df_encoded = pd.concat(chunks, axis=0)

# Save the processed DataFrame with encoded categories
df_encoded.to_csv(output_file_path, index=False)

# Display the processed DataFrame
print("\nProcessed DataFrame with encoded categories:")
print(df_encoded.head())
print(f"Shape of processed DataFrame: {df_encoded.shape}")

# Display the number of unique values per column after encoding
print("\nNumber of unique values per column after encoding:")
for col in df_encoded.columns:
    num_unique_values = df_encoded[col].nunique()
    print(f"{col}: {num_unique_values}")

# Check unique values in 'IncidentGrade'
unique_values = df_encoded['IncidentGrade'].unique()
print("\nUnique values in 'IncidentGrade':")
print(unique_values)
# Out:
# Processed DataFrame with encoded categories:
#    OrgId  DetectorId  AlertTitle  Category  IncidentGrade  EntityType  \
# 0      4           4           4         4              0           3
# 1      5           2           2         0              0           1
# 2      4           4           4         4              0           4
# 3      4           0           0         2              1           4
# 4      4           4           4         4              0           3
#
#    EvidenceRole  ApplicationName  OSFamily  OSVersion  CountryCode  State  \
# 0             0                3         4          3            3      2
# 1             0                3         0          0            3      2
# 2             1                3         4          3            3      2
# 3             1                3         4          3            3      2
# 4             0                3         4          3            3      2
#
#    City  Year  Month  DayOfWeek  Hour
# 0     2     1      3          1     4
# 1     2     1      3          0     4
# 2     2     1      3          4     4
# 3     2     1      3          2     4
# 4     2     1      3          3     5
# Shape of processed DataFrame: (3922695, 17)
#
# Number of unique values per column after encoding:
# OrgId: 6
# DetectorId: 6
# AlertTitle: 6
# Category: 6
# IncidentGrade: 3
# EntityType: 6
# EvidenceRole: 2
# ApplicationName: 6
# OSFamily: 5
# OSVersion: 6
# CountryCode: 6
# State: 6
# City: 6
# Year: 2
# Month: 6
# DayOfWeek: 6
# Hour: 6
#
# Unique values in 'IncidentGrade':
# [0 1 2]

# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest, chi2

# Read the CSV file
file_path = r"./data/top_n_categories_encoded_testing.csv"
df = pd.read_csv(file_path)

# Drop the 'Year' column
if 'Year' in df.columns:
    df.drop(columns=['Year'], inplace=True)
    print("Dropped 'Year' column.")
else:
    print("'Year' column not found in the dataset.")

# Define the features (X) and the target (y)
X = df.drop(columns=['IncidentGrade'])
y = df['IncidentGrade']

# Perform Chi-Square test
chi2_selector = SelectKBest(chi2, k='all')
chi2_selector.fit(X, y)

# Create DataFrame to view scores and p-values
chi2_scores = pd.DataFrame({
    'Feature': X.columns,
    'Chi2 Score': chi2_selector.scores_,
    'P-value': chi2_selector.pvalues_
})

# Sort by Chi2 Score
chi2_scores = chi2_scores.sort_values(by='Chi2 Score', ascending=False)

# Print Chi2 Scores and P-values
print(chi2_scores)

# Select features based on Chi-Square p-values
selected_features_chi = chi2_scores[chi2_scores['P-value'] < 0.05]['Feature'].tolist()
print("Selected Features:", selected_features_chi)

# Create a DataFrame with the selected features and include the target variable
df_selected_features = df[selected_features_chi + ['IncidentGrade']]

# Save the selected features to a new CSV file
output_file_path = r"./data/selected_features_testing_2.csv"
df_selected_features.to_csv(output_file_path, index=False)
print(f"Selected features saved to {output_file_path}")
# Out:
# Dropped 'Year' column.
#             Feature     Chi2 Score        P-value
# 2        AlertTitle  403529.211135   0.000000e+00
# 0             OrgId  385835.162827   0.000000e+00
# 1        DetectorId  273596.602925   0.000000e+00
# 5      EvidenceRole   53867.596599   0.000000e+00
# 4        EntityType   21051.747123   0.000000e+00
# 3          Category   13906.299962   0.000000e+00
# 11             City   13207.917407   0.000000e+00
# 10            State   11727.013271   0.000000e+00
# 12            Month    2980.420409   0.000000e+00
# 13        DayOfWeek    2645.199986   0.000000e+00
# 14             Hour    2139.855359   0.000000e+00
# 7          OSFamily    1541.030522   0.000000e+00
# 8         OSVersion    1300.922111  3.223687e-283
# 9       CountryCode     994.641174  1.038516e-216
# 6   ApplicationName     185.946724   4.189691e-41
# Selected Features: ['AlertTitle', 'OrgId', 'DetectorId', 'EvidenceRole', 'EntityType', 'Category', 'City', 'State', 'Month', 'DayOfWeek', 'Hour', 'OSFamily', 'OSVersion', 'CountryCode', 'ApplicationName']
# Selected features saved to ./data/selected_features_testing_2.csv

# %%
import pandas as pd

# Define the file path and the desired column order
file_path = r"./data/selected_features_testing_2.csv"
desired_column_order = ['OrgId', 'AlertTitle', 'EntityType', 'DetectorId', 'Category', 'EvidenceRole', 'City', 'State', 'OSFamily', 'OSVersion', 'Hour',
                        'CountryCode', 'DayOfWeek', 'Month', 'ApplicationName','IncidentGrade']
# Read the CSV file
df = pd.read_csv(file_path)

# Reorder the columns
df = df[desired_column_order]

# Save the DataFrame with the reordered columns to a new CSV file
output_file_path = r"./data/selected_features_testing_2_ordered.csv"
df.to_csv(output_file_path, index=False)
print(f"Data with reordered columns saved to {output_file_path}")
# Out:
# Data with reordered columns saved to ./data/selected_features_testing_2_ordered.csv
